# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import roc_curve
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import pandas as pd

DATA_PATH_TRAIN_VAL = '/content/drive/My Drive/MSc_Project_Colab/Holdout_Json/hold-out_warblr_train_val.json'
DATA_PATH_TEST = '/content/drive/My Drive/MSc_Project_Colab/Holdout_Json/hold-out_warblr_test.json'

def load_data(data_path_train_val, data_path_test):
    """Loads training and test datasets from json files.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path_train_val, "r") as fp:
      data = json.load(fp)

    X = np.array(data["log mel spectrogram"])
    y = np.array(data["labels"])

    with open(data_path_test, "r") as fp:
      data = json.load(fp)

    X_test = np.array(data["log mel spectrogram"])
    y_test = np.array(data["labels"])
    z_test = np.array(data["filenames"])

    return X, y, X_test, y_test, z_test


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train acc")
    axs[0].plot(history.history["val_accuracy"], label="val acc")
    axs[0].set_ylabel("Accuracy")
    axs[1].set_xlabel("Epoch")
    axs[0].legend(loc="lower right")
    # axs[0].set_title("Accuracy")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train loss")
    axs[1].plot(history.history["val_loss"], label="val loss")
    axs[1].set_ylabel("Loss")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    # axs[1].set_title("Loss")

    plt.show()


def prepare_datasets(validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y, X_test, y_test, z_test = load_data(DATA_PATH_TRAIN_VAL, DATA_PATH_TEST)

    # shuffle test data
    X_test, y_test, z_test = shuffle(X_test, y_test, z_test, random_state=2)

    # create the train/validation split
    X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=validation_size, random_state=2)


    # TF expects a 3D array -> (# time bins, # mel bands, # colours)
    X_train = X_train[..., np.newaxis] # 4D array -> (# samples, # time bins, # mel bands, # colours)
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]


    return X_train, X_validation, X_test, y_train, y_validation, y_test, z_test


def build_model(input_shape):
    """Generates CNN model

    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 4th conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed to dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(256))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    # model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Dense(32))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    # model.add(keras.layers.Dropout(0.4))


    # output layer
    model.add(keras.layers.Dense(1, activation='sigmoid'))

    return model


def predict(model, X, y, z):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    

    # perform prediction
    prediction = model.predict(X)

    print("Probability: {}".format(model.predict(X)))

    thresh = 0.5

    if  y == 0:
        dataLabel = "BIRD!"
    else:
        dataLabel = "NO BIRD!"

    if model.predict(X)<= thresh:
        myPrediction = "BIRD?"
    else:
        myPrediction = "NO BIRD?"

    print("Predicted: {}, Expected: {}, File: {}".format(myPrediction, dataLabel, z))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test, z_test = prepare_datasets(0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimiser,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=64, epochs=50)

    # plot accuracy/error for training and validation
    plot_history(history)

    
    # make prediction on a sample
    for index in range(int(len(X_test) / 10)):
        X = X_test[index]
        y = y_test[index]
        z = z_test[index]
        print("Sample: {}".format(index+1))
        predict(model, X, y, z)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # ROC
    # print("X_test pre ravel: {}".format(X_test.shape))
    y_preds = model.predict(X_test).ravel()
    # print("X_test post ravel: {}".format(X_test.shape))

    fpr, tpr, thresholds = roc_curve(y_test, y_preds)
    # print("fpr: {}, tpr: {}".format(fpr, tpr))
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'y--')
    plt.plot(fpr, tpr, marker='.')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.show

    #One way to find the best threshold once we calculate the true positive 
    # and false positive rates is ...
    # The optimal cut off point would be where “true positive rate” is high 
    # and the “false positive rate” is low. 
    # Based on this logic let us find the threshold where tpr-(1-fpr) is zero (or close to 0)
    
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'tf' : pd.Series(tpr-(1-fpr), index=i), 'thresholds' : pd.Series(thresholds, index=i)})
    ideal_roc_thresh = roc.iloc[(roc.tf-0).abs().argsort()[:1]]  #Locate the point where the value is close to 0
    print("Ideal threshold is: ", ideal_roc_thresh['thresholds']) 

    #Now use this threshold value in the confusion matrix to visualize the balance
    #between tp, fp, fp, and fn

    # AUC
    from sklearn.metrics import auc
    auc_value = auc(fpr, tpr)
    print("Area under curve, AUC = ", auc_value)

    # confusion matrix
    my_threshold = 0.5

    y_pred = (model.predict(X_test)>= my_threshold).astype(int)
    cm = confusion_matrix(y_test, y_pred)
    # print(cm)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["bird", "no bird"])
    disp.plot()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 429, 126, 16)      160
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 429, 126, 16)      0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 215, 63, 16)       0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 215, 63, 16)       64
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 213, 61, 16)       2320
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 213, 61, 16)       0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 107, 31, 16)       0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 107, 31, 16)       64
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 107, 29, 16)       784
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 107, 29, 16)       0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 54, 15, 16)        0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 54, 15, 16)        64
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 54, 13, 16)        784
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 54, 13, 16)        0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 27, 7, 16)         0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 27, 7, 16)         64
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 3024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               774400
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                8224
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 786,961
# Trainable params: 786,833
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/50
# 12/12 [==============================] - 1s 52ms/step - loss: 0.9949 - accuracy: 0.5638 - val_loss: 1.1749 - val_accuracy: 0.5519
# Epoch 2/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.6262 - accuracy: 0.6626 - val_loss: 0.7450 - val_accuracy: 0.5792
# Epoch 3/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.5323 - accuracy: 0.7188 - val_loss: 0.8042 - val_accuracy: 0.5792
# Epoch 4/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.4409 - accuracy: 0.7901 - val_loss: 0.7590 - val_accuracy: 0.5847
# Epoch 5/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.3529 - accuracy: 0.8436 - val_loss: 0.7414 - val_accuracy: 0.6230
# Epoch 6/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.3044 - accuracy: 0.8765 - val_loss: 1.0133 - val_accuracy: 0.5137
# Epoch 7/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.2059 - accuracy: 0.9342 - val_loss: 0.7796 - val_accuracy: 0.6175
# Epoch 8/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.1858 - accuracy: 0.9328 - val_loss: 0.7119 - val_accuracy: 0.5956
# Epoch 9/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.1511 - accuracy: 0.9602 - val_loss: 0.8306 - val_accuracy: 0.6393
# Epoch 10/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0840 - accuracy: 0.9835 - val_loss: 0.7160 - val_accuracy: 0.6612
# Epoch 11/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0411 - accuracy: 0.9959 - val_loss: 0.7650 - val_accuracy: 0.6612
# Epoch 12/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0342 - accuracy: 0.9945 - val_loss: 0.7888 - val_accuracy: 0.6339
# Epoch 13/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0207 - accuracy: 0.9986 - val_loss: 0.8802 - val_accuracy: 0.6667
# Epoch 14/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0186 - accuracy: 0.9986 - val_loss: 0.8138 - val_accuracy: 0.6776
# Epoch 15/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.7891 - val_accuracy: 0.6940
# Epoch 16/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.0434 - val_accuracy: 0.6557
# Epoch 17/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.9450 - val_accuracy: 0.6940
# Epoch 18/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.9943 - val_accuracy: 0.6831
# Epoch 19/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.9543 - val_accuracy: 0.6940
# Epoch 20/50
# 12/12 [==============================] - 0s 35ms/step - loss: 7.7163e-04 - accuracy: 1.0000 - val_loss: 0.9966 - val_accuracy: 0.6940
# Epoch 21/50
# 12/12 [==============================] - 0s 34ms/step - loss: 6.6269e-04 - accuracy: 1.0000 - val_loss: 1.0438 - val_accuracy: 0.7049
# Epoch 22/50
# 12/12 [==============================] - 0s 34ms/step - loss: 5.4228e-04 - accuracy: 1.0000 - val_loss: 1.0634 - val_accuracy: 0.6995
# Epoch 23/50
# 12/12 [==============================] - 0s 35ms/step - loss: 4.8786e-04 - accuracy: 1.0000 - val_loss: 1.1073 - val_accuracy: 0.6995
# Epoch 24/50
# 12/12 [==============================] - 0s 34ms/step - loss: 4.6759e-04 - accuracy: 1.0000 - val_loss: 1.1239 - val_accuracy: 0.6995
# Epoch 25/50
# 12/12 [==============================] - 0s 35ms/step - loss: 4.0105e-04 - accuracy: 1.0000 - val_loss: 1.1551 - val_accuracy: 0.7049
# Epoch 26/50
# 12/12 [==============================] - 0s 35ms/step - loss: 3.6580e-04 - accuracy: 1.0000 - val_loss: 1.1727 - val_accuracy: 0.6995
# Epoch 27/50
# 12/12 [==============================] - 0s 35ms/step - loss: 3.7595e-04 - accuracy: 1.0000 - val_loss: 1.2046 - val_accuracy: 0.7104
# Epoch 28/50
# 12/12 [==============================] - 0s 35ms/step - loss: 2.8673e-04 - accuracy: 1.0000 - val_loss: 1.2301 - val_accuracy: 0.7104
# Epoch 29/50
# 12/12 [==============================] - 0s 35ms/step - loss: 2.9716e-04 - accuracy: 1.0000 - val_loss: 1.2463 - val_accuracy: 0.7104
# Epoch 30/50
# 12/12 [==============================] - 0s 35ms/step - loss: 2.7683e-04 - accuracy: 1.0000 - val_loss: 1.2601 - val_accuracy: 0.6995
# Epoch 31/50
# 12/12 [==============================] - 0s 37ms/step - loss: 2.6761e-04 - accuracy: 1.0000 - val_loss: 1.2799 - val_accuracy: 0.6995
# Epoch 32/50
# 12/12 [==============================] - 0s 34ms/step - loss: 2.7673e-04 - accuracy: 1.0000 - val_loss: 1.3008 - val_accuracy: 0.6940
# Epoch 33/50
# 12/12 [==============================] - 0s 35ms/step - loss: 2.0714e-04 - accuracy: 1.0000 - val_loss: 1.3258 - val_accuracy: 0.6940
# Epoch 34/50
# 12/12 [==============================] - 0s 35ms/step - loss: 2.4518e-04 - accuracy: 1.0000 - val_loss: 1.3304 - val_accuracy: 0.7049
# Epoch 35/50
# 12/12 [==============================] - 0s 34ms/step - loss: 2.0852e-04 - accuracy: 1.0000 - val_loss: 1.3441 - val_accuracy: 0.7049
# Epoch 36/50
# 12/12 [==============================] - 0s 36ms/step - loss: 1.9910e-04 - accuracy: 1.0000 - val_loss: 1.3547 - val_accuracy: 0.7049
# Epoch 37/50
# 12/12 [==============================] - 0s 34ms/step - loss: 2.4014e-04 - accuracy: 1.0000 - val_loss: 1.3657 - val_accuracy: 0.7049
# Epoch 38/50
# 12/12 [==============================] - 0s 35ms/step - loss: 1.6840e-04 - accuracy: 1.0000 - val_loss: 1.3745 - val_accuracy: 0.7049
# Epoch 39/50
# 12/12 [==============================] - 0s 34ms/step - loss: 1.5567e-04 - accuracy: 1.0000 - val_loss: 1.3842 - val_accuracy: 0.7049
# Epoch 40/50
# 12/12 [==============================] - 0s 35ms/step - loss: 1.4273e-04 - accuracy: 1.0000 - val_loss: 1.3919 - val_accuracy: 0.7104
# Epoch 41/50
# 12/12 [==============================] - 0s 36ms/step - loss: 1.3955e-04 - accuracy: 1.0000 - val_loss: 1.4092 - val_accuracy: 0.7049
# Epoch 42/50
# 12/12 [==============================] - 0s 35ms/step - loss: 1.5273e-04 - accuracy: 1.0000 - val_loss: 1.4193 - val_accuracy: 0.7049
# Epoch 43/50
# 12/12 [==============================] - 0s 35ms/step - loss: 1.3791e-04 - accuracy: 1.0000 - val_loss: 1.4270 - val_accuracy: 0.7049
# Epoch 44/50
# 12/12 [==============================] - 0s 35ms/step - loss: 1.2625e-04 - accuracy: 1.0000 - val_loss: 1.4363 - val_accuracy: 0.7049
# Epoch 45/50
# 12/12 [==============================] - 0s 35ms/step - loss: 1.2451e-04 - accuracy: 1.0000 - val_loss: 1.4413 - val_accuracy: 0.7049
# Epoch 46/50
# 12/12 [==============================] - 0s 35ms/step - loss: 1.2160e-04 - accuracy: 1.0000 - val_loss: 1.4497 - val_accuracy: 0.7049
# Epoch 47/50
# 12/12 [==============================] - 0s 34ms/step - loss: 1.0893e-04 - accuracy: 1.0000 - val_loss: 1.4556 - val_accuracy: 0.7104
# Epoch 48/50
# 12/12 [==============================] - 0s 35ms/step - loss: 1.1951e-04 - accuracy: 1.0000 - val_loss: 1.4634 - val_accuracy: 0.7049
# Epoch 49/50
# 12/12 [==============================] - 0s 36ms/step - loss: 1.1301e-04 - accuracy: 1.0000 - val_loss: 1.4669 - val_accuracy: 0.7049
# Epoch 50/50
# 12/12 [==============================] - 0s 35ms/step - loss: 1.2462e-04 - accuracy: 1.0000 - val_loss: 1.4681 - val_accuracy: 0.7049
# Sample: 1
# Probability: [[0.00137865]]
# Predicted: BIRD?, Expected: NO BIRD!, File: ff8de3d9-ae5a-420d-aff5.wav
# Sample: 2
# Probability: [[0.9965655]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: f083677b-a486-4bdc-9c3d.wav
# Sample: 3
# Probability: [[0.00239984]]
# Predicted: BIRD?, Expected: BIRD!, File: 0a4ef72d-611f-4adc-9cf1.wav
# Sample: 4
# Probability: [[0.9968125]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: 000e088a-69f7-4d7a-ba7b.wav
# Sample: 5
# Probability: [[4.720357e-07]]
# Predicted: BIRD?, Expected: BIRD!, File: fe7ef707-ca9b-48dc-8a2b.wav
# Sample: 6
# Probability: [[0.31992006]]
# Predicted: BIRD?, Expected: BIRD!, File: 0a69a7ce-5aeb-4627-9266.wav
# Sample: 7
# Probability: [[0.3438337]]
# Predicted: BIRD?, Expected: NO BIRD!, File: 0eacbedf-b03b-47a4-8e71.wav
# Sample: 8
# Probability: [[0.74122906]]
# Predicted: NO BIRD?, Expected: BIRD!, File: ff605fcf-3fa0-499e-b821.wav
# Sample: 9
# Probability: [[6.74175e-11]]
# Predicted: BIRD?, Expected: BIRD!, File: fecf3726-c479-45c0-8048.wav
# Sample: 10
# Probability: [[0.9930226]]
# Predicted: NO BIRD?, Expected: BIRD!, File: 0b7d8a53-ceea-4050-976f.wav
# Sample: 11
# Probability: [[0.30831122]]
# Predicted: BIRD?, Expected: BIRD!, File: ff590119-21c3-44ed-9043.wav
# Sample: 12
# Probability: [[1.1444689e-06]]
# Predicted: BIRD?, Expected: NO BIRD!, File: 1a4c4f65-3b3e-40bd-bdf1.wav
# Sample: 13
# Probability: [[0.3975848]]
# Predicted: BIRD?, Expected: NO BIRD!, File: fb85033b-1b35-4e7f-894f.wav
# Sample: 14
# Probability: [[4.2888133e-09]]
# Predicted: BIRD?, Expected: BIRD!, File: 00ed8c75-160e-462d-b7b6.wav
# Sample: 15
# Probability: [[0.03479003]]
# Predicted: BIRD?, Expected: BIRD!, File: 0a9da934-d6ac-48f1-9739.wav
# Sample: 16
# Probability: [[0.894328]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: 0f333169-cf20-463d-8b03.wav
# Sample: 17
# Probability: [[0.01258455]]
# Predicted: BIRD?, Expected: BIRD!, File: 0a160dd5-9c7e-4e2f-8bd7.wav
# Sample: 18
# Probability: [[0.99997914]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: 1a8fbdbb-f3e7-4506-8669.wav
# Sample: 19
# Probability: [[0.9774925]]
# Predicted: NO BIRD?, Expected: BIRD!, File: ff264b32-ee67-4098-abbb.wav
# Sample: 20
# Probability: [[0.0287329]]
# Predicted: BIRD?, Expected: BIRD!, File: 0a7e2a2a-a679-4c5c-818f.wav
# Sample: 21
# Probability: [[0.99997544]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: 0a0b783d-f9a3-4652-a01d.wav
# Sample: 22
# Probability: [[0.00064427]]
# Predicted: BIRD?, Expected: NO BIRD!, File: 0e0b9ab5-ed1f-4100-8865.wav
# 7/7 - 0s - loss: 2.8348 - accuracy: 0.6071
#
# Test accuracy: 0.6071428656578064
# Ideal threshold is:  67    0.143243
# Name: thresholds, dtype: float32
# Area under curve, AUC =  0.6350554093916925
