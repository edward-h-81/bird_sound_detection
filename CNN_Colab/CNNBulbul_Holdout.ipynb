# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import roc_curve
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import pandas as pd

DATA_PATH_TRAIN_VAL = '/content/drive/My Drive/MSc_Project_Colab/Holdout_Json/hold-out_warblr_train_val.json'
DATA_PATH_TEST = '/content/drive/My Drive/MSc_Project_Colab/Holdout_Json/hold-out_warblr_test.json'

def load_data(data_path_train_val, data_path_test):
    """Loads training and test datasets from json files.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path_train_val, "r") as fp:
      data = json.load(fp)

    X = np.array(data["log mel spectrogram"])
    y = np.array(data["labels"])

    with open(data_path_test, "r") as fp:
      data = json.load(fp)

    X_test = np.array(data["log mel spectrogram"])
    y_test = np.array(data["labels"])
    z_test = np.array(data["filenames"])

    return X, y, X_test, y_test, z_test


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train acc")
    axs[0].plot(history.history["val_accuracy"], label="val acc")
    axs[0].set_ylabel("Accuracy")
    axs[1].set_xlabel("Epoch")
    axs[0].legend(loc="lower right")
    # axs[0].set_title("Accuracy")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train loss")
    axs[1].plot(history.history["val_loss"], label="val loss")
    axs[1].set_ylabel("Loss")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    # axs[1].set_title("Loss")

    plt.show()


def prepare_datasets(validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y, X_test, y_test, z_test = load_data(DATA_PATH_TRAIN_VAL, DATA_PATH_TEST)

    # shuffle test data
    X_test, y_test, z_test = shuffle(X_test, y_test, z_test, random_state=0)

    # create the train/validation split
    X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=validation_size, random_state=0)


    # TF expects a 3D array -> (# time bins, # mel bands, # colours)
    X_train = X_train[..., np.newaxis] # 4D array -> (# samples, # time bins, # mel bands, # colours)
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]


    return X_train, X_validation, X_test, y_train, y_validation, y_test, z_test


def build_model(input_shape):
    """Generates CNN model

    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 4th conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed to dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(256))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    # model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Dense(32))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    # model.add(keras.layers.Dropout(0.4))


    # output layer
    model.add(keras.layers.Dense(1, activation='sigmoid'))

    return model


def predict(model, X, y, z):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    

    # perform prediction
    prediction = model.predict(X)

    print("Probability: {}".format(model.predict(X)))

    thresh = 0.5

    if  y == 0:
        dataLabel = "BIRD!"
    else:
        dataLabel = "NO BIRD!"

    if model.predict(X)<= thresh:
        myPrediction = "BIRD?"
    else:
        myPrediction = "NO BIRD?"

    print("Predicted: {}, Expected: {}, File: {}".format(myPrediction, dataLabel, z))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test, z_test = prepare_datasets(0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimiser,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # add EarlyStopping feature
    callback = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100)
    # callback = keras.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', min_delta=1, verbose=1, patience=33)

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=64, epochs=300, callbacks=[callback])

    # early stopping
    len(history.history['val_loss'])

    # plot accuracy/error for training and validation
    plot_history(history)

    
    # make prediction on a sample
    for index in range(int(len(X_test) / 10)):
        X = X_test[index]
        y = y_test[index]
        z = z_test[index]
        print("Sample: {}".format(index+1))
        predict(model, X, y, z)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # ROC
    # print("X_test pre ravel: {}".format(X_test.shape))
    y_preds = model.predict(X_test).ravel()
    # print("X_test post ravel: {}".format(X_test.shape))

    fpr, tpr, thresholds = roc_curve(y_test, y_preds)
    # print("fpr: {}, tpr: {}".format(fpr, tpr))
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'y--')
    plt.plot(fpr, tpr, marker='.')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.show

    #One way to find the best threshold once we calculate the true positive 
    # and false positive rates is ...
    # The optimal cut off point would be where “true positive rate” is high 
    # and the “false positive rate” is low. 
    # Based on this logic let us find the threshold where tpr-(1-fpr) is zero (or close to 0)
    
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'tf' : pd.Series(tpr-(1-fpr), index=i), 'thresholds' : pd.Series(thresholds, index=i)})
    ideal_roc_thresh = roc.iloc[(roc.tf-0).abs().argsort()[:1]]  #Locate the point where the value is close to 0
    print("Ideal threshold is: ", ideal_roc_thresh['thresholds']) 

    #Now use this threshold value in the confusion matrix to visualize the balance
    #between tp, fp, fp, and fn

    # AUC
    from sklearn.metrics import auc
    auc_value = auc(fpr, tpr)
    print("Area under curve, AUC = ", auc_value)

    # confusion matrix
    my_threshold = 0.5

    y_pred = (model.predict(X_test)>= my_threshold).astype(int)
    cm = confusion_matrix(y_test, y_pred)
    # print(cm)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["bird", "no bird"])
    disp.plot()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_48 (Conv2D)           (None, 429, 126, 16)      160
# _________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)   (None, 429, 126, 16)      0
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 215, 63, 16)       0
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 215, 63, 16)       64
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 213, 61, 16)       2320
# _________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)   (None, 213, 61, 16)       0
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 107, 31, 16)       0
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 107, 31, 16)       64
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 107, 29, 16)       784
# _________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)   (None, 107, 29, 16)       0
# _________________________________________________________________
# max_pooling2d_50 (MaxPooling (None, 54, 15, 16)        0
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 54, 15, 16)        64
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 54, 13, 16)        784
# _________________________________________________________________
# leaky_re_lu_75 (LeakyReLU)   (None, 54, 13, 16)        0
# _________________________________________________________________
# max_pooling2d_51 (MaxPooling (None, 27, 7, 16)         0
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 27, 7, 16)         64
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 3024)              0
# _________________________________________________________________
# dense_36 (Dense)             (None, 256)               774400
# _________________________________________________________________
# leaky_re_lu_76 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 32)                8224
# _________________________________________________________________
# leaky_re_lu_77 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dense_38 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 786,961
# Trainable params: 786,833
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/300
# 12/12 [==============================] - 1s 55ms/step - loss: 1.2625 - accuracy: 0.5514 - val_loss: 2.0228 - val_accuracy: 0.5137
# Epoch 2/300
# 12/12 [==============================] - 0s 36ms/step - loss: 0.6525 - accuracy: 0.6187 - val_loss: 0.7822 - val_accuracy: 0.5027
# Epoch 3/300
# 12/12 [==============================] - 0s 36ms/step - loss: 0.6395 - accuracy: 0.6571 - val_loss: 0.9201 - val_accuracy: 0.5355
# Epoch 4/300
# 12/12 [==============================] - 0s 36ms/step - loss: 0.5260 - accuracy: 0.7119 - val_loss: 0.7086 - val_accuracy: 0.5628
# Epoch 5/300
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4674 - accuracy: 0.7723 - val_loss: 0.6533 - val_accuracy: 0.6011
# Epoch 6/300
# 12/12 [==============================] - 0s 36ms/step - loss: 0.4003 - accuracy: 0.8615 - val_loss: 0.6617 - val_accuracy: 0.6721
# Epoch 7/300
# 12/12 [==============================] - 0s 36ms/step - loss: 0.3423 - accuracy: 0.8793 - val_loss: 0.6428 - val_accuracy: 0.6612
# Epoch 8/300
# 12/12 [==============================] - 0s 36ms/step - loss: 0.2914 - accuracy: 0.9136 - val_loss: 0.6302 - val_accuracy: 0.6230
# Epoch 9/300
# 12/12 [==============================] - 0s 36ms/step - loss: 0.2615 - accuracy: 0.8985 - val_loss: 0.6688 - val_accuracy: 0.6066
# Epoch 10/300
# 12/12 [==============================] - 0s 35ms/step - loss: 0.1929 - accuracy: 0.9451 - val_loss: 0.6349 - val_accuracy: 0.6448
# Epoch 11/300
# 12/12 [==============================] - 0s 34ms/step - loss: 0.1247 - accuracy: 0.9781 - val_loss: 0.6763 - val_accuracy: 0.6393
# Epoch 12/300
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0882 - accuracy: 0.9822 - val_loss: 0.6523 - val_accuracy: 0.6612
# Epoch 13/300
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0611 - accuracy: 0.9931 - val_loss: 0.6903 - val_accuracy: 0.6448
# Epoch 14/300
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0410 - accuracy: 0.9986 - val_loss: 0.7288 - val_accuracy: 0.6284
# Epoch 15/300
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.8231 - val_accuracy: 0.5902
# Epoch 16/300
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.8641 - val_accuracy: 0.6011
# Epoch 17/300
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0111 - accuracy: 0.9986 - val_loss: 0.9970 - val_accuracy: 0.6066
# Epoch 18/300
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.9553 - val_accuracy: 0.6393
# Epoch 19/300
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.0343 - val_accuracy: 0.5847
# Epoch 20/300
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.0544 - val_accuracy: 0.6339
# Epoch 21/300
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.1143 - val_accuracy: 0.6120
# Epoch 22/300
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.1579 - val_accuracy: 0.6339
# Epoch 23/300
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.2033 - val_accuracy: 0.6339
# Epoch 24/300
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.2684 - val_accuracy: 0.6175
# Epoch 25/300
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.2935 - val_accuracy: 0.6230
# Epoch 26/300
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.3480 - val_accuracy: 0.6339
# Epoch 27/300
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.3882 - val_accuracy: 0.6448
# Epoch 28/300
# 12/12 [==============================] - 0s 36ms/step - loss: 9.2602e-04 - accuracy: 1.0000 - val_loss: 1.4473 - val_accuracy: 0.6011
# Epoch 29/300
# 12/12 [==============================] - 0s 34ms/step - loss: 8.1912e-04 - accuracy: 1.0000 - val_loss: 1.4849 - val_accuracy: 0.6175
# Epoch 30/300
# 12/12 [==============================] - 0s 37ms/step - loss: 7.9232e-04 - accuracy: 1.0000 - val_loss: 1.5147 - val_accuracy: 0.6175
# Epoch 31/300
# 12/12 [==============================] - 0s 37ms/step - loss: 8.2043e-04 - accuracy: 1.0000 - val_loss: 1.5547 - val_accuracy: 0.6066
# Epoch 32/300
# 12/12 [==============================] - 0s 36ms/step - loss: 6.5310e-04 - accuracy: 1.0000 - val_loss: 1.5835 - val_accuracy: 0.6284
# Epoch 33/300
# 12/12 [==============================] - 0s 36ms/step - loss: 5.6059e-04 - accuracy: 1.0000 - val_loss: 1.6064 - val_accuracy: 0.6066
# Epoch 34/300
# 12/12 [==============================] - 0s 36ms/step - loss: 6.8209e-04 - accuracy: 1.0000 - val_loss: 1.6405 - val_accuracy: 0.6066
# Epoch 35/300
# 12/12 [==============================] - 0s 35ms/step - loss: 5.8811e-04 - accuracy: 1.0000 - val_loss: 1.6741 - val_accuracy: 0.6175
# Epoch 36/300
# 12/12 [==============================] - 0s 37ms/step - loss: 4.5837e-04 - accuracy: 1.0000 - val_loss: 1.6915 - val_accuracy: 0.6120
# Epoch 37/300
# 12/12 [==============================] - 0s 36ms/step - loss: 4.4347e-04 - accuracy: 1.0000 - val_loss: 1.7227 - val_accuracy: 0.6066
# Epoch 38/300
# 12/12 [==============================] - 0s 35ms/step - loss: 4.2619e-04 - accuracy: 1.0000 - val_loss: 1.7559 - val_accuracy: 0.6066
# Epoch 39/300
# 12/12 [==============================] - 0s 36ms/step - loss: 3.7409e-04 - accuracy: 1.0000 - val_loss: 1.7859 - val_accuracy: 0.6066
# Epoch 40/300
# 12/12 [==============================] - 0s 36ms/step - loss: 3.8067e-04 - accuracy: 1.0000 - val_loss: 1.8141 - val_accuracy: 0.5956
# Epoch 41/300
# 12/12 [==============================] - 0s 36ms/step - loss: 3.5597e-04 - accuracy: 1.0000 - val_loss: 1.8282 - val_accuracy: 0.5956
# Epoch 42/300
# 12/12 [==============================] - 0s 35ms/step - loss: 3.0014e-04 - accuracy: 1.0000 - val_loss: 1.8553 - val_accuracy: 0.6066
# Epoch 43/300
# 12/12 [==============================] - 0s 36ms/step - loss: 3.5665e-04 - accuracy: 1.0000 - val_loss: 1.8593 - val_accuracy: 0.6011
# Epoch 44/300
# 12/12 [==============================] - 0s 36ms/step - loss: 2.9268e-04 - accuracy: 1.0000 - val_loss: 1.8762 - val_accuracy: 0.6066
# Epoch 45/300
# 12/12 [==============================] - 0s 35ms/step - loss: 2.7399e-04 - accuracy: 1.0000 - val_loss: 1.8989 - val_accuracy: 0.6066
# Epoch 46/300
# 12/12 [==============================] - 0s 35ms/step - loss: 2.6483e-04 - accuracy: 1.0000 - val_loss: 1.9183 - val_accuracy: 0.6175
# Epoch 47/300
# 12/12 [==============================] - 0s 36ms/step - loss: 2.3444e-04 - accuracy: 1.0000 - val_loss: 1.9333 - val_accuracy: 0.6120
# Epoch 48/300
# 12/12 [==============================] - 0s 36ms/step - loss: 2.7514e-04 - accuracy: 1.0000 - val_loss: 1.9486 - val_accuracy: 0.6011
# Epoch 49/300
# 12/12 [==============================] - 0s 35ms/step - loss: 2.2999e-04 - accuracy: 1.0000 - val_loss: 1.9588 - val_accuracy: 0.6066
# Epoch 50/300
# 12/12 [==============================] - 0s 35ms/step - loss: 2.2253e-04 - accuracy: 1.0000 - val_loss: 1.9616 - val_accuracy: 0.6120
# Epoch 51/300
# 12/12 [==============================] - 0s 35ms/step - loss: 2.4007e-04 - accuracy: 1.0000 - val_loss: 1.9703 - val_accuracy: 0.6011
# Epoch 52/300
# 12/12 [==============================] - 0s 35ms/step - loss: 2.1947e-04 - accuracy: 1.0000 - val_loss: 1.9791 - val_accuracy: 0.6011
# Epoch 53/300
# 12/12 [==============================] - 0s 36ms/step - loss: 2.1678e-04 - accuracy: 1.0000 - val_loss: 1.9736 - val_accuracy: 0.6011
# Epoch 54/300
# 12/12 [==============================] - 0s 36ms/step - loss: 2.3499e-04 - accuracy: 1.0000 - val_loss: 1.9967 - val_accuracy: 0.6066
# Epoch 55/300
# 12/12 [==============================] - 0s 36ms/step - loss: 2.1012e-04 - accuracy: 1.0000 - val_loss: 2.0184 - val_accuracy: 0.6011
# Epoch 56/300
# 12/12 [==============================] - 0s 34ms/step - loss: 2.0321e-04 - accuracy: 1.0000 - val_loss: 2.0366 - val_accuracy: 0.6120
# Epoch 57/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.7372e-04 - accuracy: 1.0000 - val_loss: 2.0573 - val_accuracy: 0.6120
# Epoch 58/300
# 12/12 [==============================] - 0s 35ms/step - loss: 1.4903e-04 - accuracy: 1.0000 - val_loss: 2.0691 - val_accuracy: 0.6066
# Epoch 59/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.7111e-04 - accuracy: 1.0000 - val_loss: 2.0711 - val_accuracy: 0.6066
# Epoch 60/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.7117e-04 - accuracy: 1.0000 - val_loss: 2.0793 - val_accuracy: 0.6066
# Epoch 61/300
# 12/12 [==============================] - 0s 37ms/step - loss: 1.4914e-04 - accuracy: 1.0000 - val_loss: 2.0962 - val_accuracy: 0.6066
# Epoch 62/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.5162e-04 - accuracy: 1.0000 - val_loss: 2.1102 - val_accuracy: 0.6011
# Epoch 63/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.3200e-04 - accuracy: 1.0000 - val_loss: 2.1127 - val_accuracy: 0.5956
# Epoch 64/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.2547e-04 - accuracy: 1.0000 - val_loss: 2.1136 - val_accuracy: 0.5956
# Epoch 65/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.2564e-04 - accuracy: 1.0000 - val_loss: 2.1211 - val_accuracy: 0.6066
# Epoch 66/300
# 12/12 [==============================] - 0s 35ms/step - loss: 1.5431e-04 - accuracy: 1.0000 - val_loss: 2.1732 - val_accuracy: 0.6011
# Epoch 67/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.1451e-04 - accuracy: 1.0000 - val_loss: 2.1780 - val_accuracy: 0.6066
# Epoch 68/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.2864e-04 - accuracy: 1.0000 - val_loss: 2.1657 - val_accuracy: 0.6066
# Epoch 69/300
# 12/12 [==============================] - 0s 35ms/step - loss: 1.4368e-04 - accuracy: 1.0000 - val_loss: 2.1453 - val_accuracy: 0.6120
# Epoch 70/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.1026e-04 - accuracy: 1.0000 - val_loss: 2.1496 - val_accuracy: 0.5956
# Epoch 71/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.1646e-04 - accuracy: 1.0000 - val_loss: 2.1572 - val_accuracy: 0.6011
# Epoch 72/300
# 12/12 [==============================] - 0s 35ms/step - loss: 1.0808e-04 - accuracy: 1.0000 - val_loss: 2.1716 - val_accuracy: 0.6066
# Epoch 73/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.0606e-04 - accuracy: 1.0000 - val_loss: 2.1815 - val_accuracy: 0.6066
# Epoch 74/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.0306e-04 - accuracy: 1.0000 - val_loss: 2.1861 - val_accuracy: 0.6011
# Epoch 75/300
# 12/12 [==============================] - 0s 36ms/step - loss: 9.7888e-05 - accuracy: 1.0000 - val_loss: 2.1832 - val_accuracy: 0.5956
# Epoch 76/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.7425e-04 - accuracy: 1.0000 - val_loss: 2.1782 - val_accuracy: 0.6066
# Epoch 77/300
# 12/12 [==============================] - 0s 37ms/step - loss: 3.5209e-04 - accuracy: 1.0000 - val_loss: 2.1414 - val_accuracy: 0.6066
# Epoch 78/300
# 12/12 [==============================] - 0s 36ms/step - loss: 3.1794e-04 - accuracy: 1.0000 - val_loss: 2.1257 - val_accuracy: 0.6448
# Epoch 79/300
# 12/12 [==============================] - 0s 35ms/step - loss: 1.8793e-04 - accuracy: 1.0000 - val_loss: 2.2060 - val_accuracy: 0.6066
# Epoch 80/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.2718e-04 - accuracy: 1.0000 - val_loss: 2.2134 - val_accuracy: 0.6011
# Epoch 81/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.0970e-04 - accuracy: 1.0000 - val_loss: 2.2072 - val_accuracy: 0.6066
# Epoch 82/300
# 12/12 [==============================] - 0s 36ms/step - loss: 1.1112e-04 - accuracy: 1.0000 - val_loss: 2.2119 - val_accuracy: 0.6066
# Epoch 83/300
# 12/12 [==============================] - 0s 36ms/step - loss: 8.4660e-05 - accuracy: 1.0000 - val_loss: 2.2212 - val_accuracy: 0.6066
# Epoch 84/300
# 12/12 [==============================] - 0s 36ms/step - loss: 9.1892e-05 - accuracy: 1.0000 - val_loss: 2.2274 - val_accuracy: 0.6066
# Epoch 85/300
# 12/12 [==============================] - 0s 35ms/step - loss: 8.1913e-05 - accuracy: 1.0000 - val_loss: 2.2233 - val_accuracy: 0.6120
# Epoch 86/300
# 12/12 [==============================] - 0s 36ms/step - loss: 8.9590e-05 - accuracy: 1.0000 - val_loss: 2.2275 - val_accuracy: 0.6120
# Epoch 87/300
# 12/12 [==============================] - 0s 35ms/step - loss: 7.1733e-05 - accuracy: 1.0000 - val_loss: 2.2251 - val_accuracy: 0.6120
# Epoch 88/300
# 12/12 [==============================] - 0s 36ms/step - loss: 7.6033e-05 - accuracy: 1.0000 - val_loss: 2.2320 - val_accuracy: 0.6120
# Epoch 89/300
# 12/12 [==============================] - 0s 36ms/step - loss: 6.5734e-05 - accuracy: 1.0000 - val_loss: 2.2393 - val_accuracy: 0.6120
# Epoch 90/300
# 12/12 [==============================] - 0s 36ms/step - loss: 6.8868e-05 - accuracy: 1.0000 - val_loss: 2.2478 - val_accuracy: 0.6066
# Epoch 91/300
# 12/12 [==============================] - 0s 35ms/step - loss: 8.3497e-05 - accuracy: 1.0000 - val_loss: 2.2502 - val_accuracy: 0.6066
# Epoch 92/300
# 12/12 [==============================] - 0s 36ms/step - loss: 5.5637e-05 - accuracy: 1.0000 - val_loss: 2.2569 - val_accuracy: 0.6066
# Epoch 93/300
# 12/12 [==============================] - 0s 34ms/step - loss: 5.7096e-05 - accuracy: 1.0000 - val_loss: 2.2614 - val_accuracy: 0.6120
# Epoch 94/300
# 12/12 [==============================] - 0s 35ms/step - loss: 6.0477e-05 - accuracy: 1.0000 - val_loss: 2.2639 - val_accuracy: 0.6120
# Epoch 95/300
# 12/12 [==============================] - 0s 35ms/step - loss: 6.2558e-05 - accuracy: 1.0000 - val_loss: 2.2675 - val_accuracy: 0.6120
# Epoch 96/300
# 12/12 [==============================] - 0s 37ms/step - loss: 7.4361e-05 - accuracy: 1.0000 - val_loss: 2.2776 - val_accuracy: 0.6120
# Epoch 97/300
# 12/12 [==============================] - 0s 36ms/step - loss: 5.3987e-05 - accuracy: 1.0000 - val_loss: 2.2851 - val_accuracy: 0.6120
# Epoch 98/300
# 12/12 [==============================] - 0s 36ms/step - loss: 5.3083e-05 - accuracy: 1.0000 - val_loss: 2.2944 - val_accuracy: 0.6120
# Epoch 99/300
# 12/12 [==============================] - 0s 36ms/step - loss: 4.5490e-05 - accuracy: 1.0000 - val_loss: 2.3026 - val_accuracy: 0.6120
# Epoch 100/300
# 12/12 [==============================] - 0s 36ms/step - loss: 4.7289e-05 - accuracy: 1.0000 - val_loss: 2.3047 - val_accuracy: 0.6120
# Epoch 101/300
# 12/12 [==============================] - 0s 36ms/step - loss: 5.1861e-05 - accuracy: 1.0000 - val_loss: 2.3126 - val_accuracy: 0.6120
# Epoch 102/300
# 12/12 [==============================] - 0s 36ms/step - loss: 5.3714e-05 - accuracy: 1.0000 - val_loss: 2.3160 - val_accuracy: 0.6120
# Epoch 103/300
# 12/12 [==============================] - 0s 37ms/step - loss: 5.3060e-05 - accuracy: 1.0000 - val_loss: 2.3221 - val_accuracy: 0.6120
# Epoch 104/300
# 12/12 [==============================] - 0s 36ms/step - loss: 4.8110e-05 - accuracy: 1.0000 - val_loss: 2.3219 - val_accuracy: 0.6066
# Epoch 105/300
# 12/12 [==============================] - 0s 36ms/step - loss: 5.0006e-05 - accuracy: 1.0000 - val_loss: 2.3253 - val_accuracy: 0.6120
# Epoch 106/300
# 12/12 [==============================] - 0s 37ms/step - loss: 5.1368e-05 - accuracy: 1.0000 - val_loss: 2.3329 - val_accuracy: 0.6066
# Epoch 107/300
# 12/12 [==============================] - 0s 36ms/step - loss: 4.3021e-05 - accuracy: 1.0000 - val_loss: 2.3332 - val_accuracy: 0.6066
# Epoch 108/300
# 12/12 [==============================] - 0s 36ms/step - loss: 4.7365e-05 - accuracy: 1.0000 - val_loss: 2.3361 - val_accuracy: 0.6120
# Epoch 00108: early stopping
# Sample: 1
# Probability: [[0.9998197]]
# Predicted: NO BIRD?, Expected: BIRD!, File: ff6840f3-e409-46cc-b3bc.wav
# Sample: 2
# Probability: [[0.9999105]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: fc3c6825-6c9c-4268-b0af.wav
# Sample: 3
# Probability: [[0.03492944]]
# Predicted: BIRD?, Expected: NO BIRD!, File: f083677b-a486-4bdc-9c3d.wav
# Sample: 4
# Probability: [[0.9999964]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: 0d92b7b9-2d41-4975-841d.wav
# Sample: 5
# Probability: [[0.99992657]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: fa080390-6c34-427f-bacf.wav
# Sample: 6
# Probability: [[0.9993517]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: 0f1a799c-4b7e-4bf7-b6aa.wav
# Sample: 7
# Probability: [[1.1873136e-06]]
# Predicted: BIRD?, Expected: BIRD!, File: 0b20b418-dcd5-49a0-9a21.wav
# Sample: 8
# Probability: [[0.00797339]]
# Predicted: BIRD?, Expected: NO BIRD!, File: fbee37a9-5ea0-4464-918d.wav
# Sample: 9
# Probability: [[2.9519628e-05]]
# Predicted: BIRD?, Expected: BIRD!, File: fe4afc2d-32bc-49c2-a145.wav
# Sample: 10
# Probability: [[0.0106994]]
# Predicted: BIRD?, Expected: BIRD!, File: 00e3f7e8-b361-46f6-9df7.wav
# Sample: 11
# Probability: [[0.00198961]]
# Predicted: BIRD?, Expected: BIRD!, File: ffe84fee-d4e6-4483-9113.wav
# Sample: 12
# Probability: [[0.00027772]]
# Predicted: BIRD?, Expected: BIRD!, File: 0aeb661d-a33e-4208-99a6.wav
# Sample: 13
# Probability: [[0.9999999]]
# Predicted: NO BIRD?, Expected: BIRD!, File: 00cc9afb-40da-4ca3-a4fe.wav
# Sample: 14
# Probability: [[0.0001915]]
# Predicted: BIRD?, Expected: NO BIRD!, File: 0e91f9aa-e50c-4700-ac7a.wav
# Sample: 15
# Probability: [[0.9993344]]
# Predicted: NO BIRD?, Expected: BIRD!, File: fe47c524-ee64-43a0-a968.wav
# Sample: 16
# Probability: [[0.99938023]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: fa568b98-bed3-4c9a-912b.wav
# Sample: 17
# Probability: [[0.9998889]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: 0dc70bfd-3633-4d35-ab74.wav
# Sample: 18
# Probability: [[0.99969864]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: fc94a529-2d53-408f-937e.wav
# Sample: 19
# Probability: [[0.03413774]]
# Predicted: BIRD?, Expected: NO BIRD!, File: fcb61b65-9a14-4add-9741.wav
# Sample: 20
# Probability: [[0.99662495]]
# Predicted: NO BIRD?, Expected: BIRD!, File: ff5989ea-d21b-4ba8-a4c1.wav
# Sample: 21
# Probability: [[0.9847498]]
# Predicted: NO BIRD?, Expected: BIRD!, File: ffeaa1c4-f880-47db-b58e.wav
# Sample: 22
# Probability: [[0.7190147]]
# Predicted: NO BIRD?, Expected: BIRD!, File: fec03f79-d181-44df-9858.wav
# 7/7 - 0s - loss: 3.1807 - accuracy: 0.5402
#
# Test accuracy: 0.5401785969734192
# Ideal threshold is:  54    0.794769
# Name: thresholds, dtype: float32
# Area under curve, AUC =  0.5670892131069123
