# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = '/content/drive/My Drive/MSc_Project_Colab/mixed_1140_1_segment_128_mels.json'


def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["log mel spectrogram"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates CNN model

    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU())
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 4th conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed to dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(256, activation='relu'))
    # model.add(keras.layers.Dropout(0.3))
    model.add(keras.layers.Dense(32, activation='relu'))
    # model.add(keras.layers.Dropout(0.3))


    # output layer
    model.add(keras.layers.Dense(2, activation='softmax'))

    return model


def predict(model, X, y):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    if y == 0:
        dataLabel = "BIRD!"
    else:
        dataLabel = "NO BIRD!"

    if predicted_index == 0:
        myPrediction = "BIRD?"
    else:
        myPrediction = "NO BIRD?"

    print("Predicted: {}, Expected: {}".format(myPrediction, dataLabel))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=64, epochs=50)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    index = 0
    # make prediction on a sample
    while index < len(X_test):
        X = X_test[index]
        y = y_test[index]
        print("Sample: {}".format(index+1))
        predict(model, X, y)
        index += 1
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 429, 126, 16)      160
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 429, 126, 16)      0
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 215, 63, 16)       0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 215, 63, 16)       64
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 213, 61, 16)       2320
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 107, 31, 16)       0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 107, 31, 16)       64
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 107, 29, 16)       784
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 54, 15, 16)        0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 54, 15, 16)        64
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 54, 13, 16)        784
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 27, 7, 16)         0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 27, 7, 16)         64
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 3024)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               774400
# _________________________________________________________________
# dense_19 (Dense)             (None, 32)                8224
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 786,994
# Trainable params: 786,866
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/50
# 11/11 [==============================] - 1s 52ms/step - loss: 0.9256 - accuracy: 0.5662 - val_loss: 1.9824 - val_accuracy: 0.4854
# Epoch 2/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.5532 - accuracy: 0.7059 - val_loss: 1.3244 - val_accuracy: 0.4971
# Epoch 3/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.4456 - accuracy: 0.7838 - val_loss: 1.2651 - val_accuracy: 0.5205
# Epoch 4/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.3443 - accuracy: 0.8397 - val_loss: 1.4303 - val_accuracy: 0.5088
# Epoch 5/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.3228 - accuracy: 0.8515 - val_loss: 0.8088 - val_accuracy: 0.5497
# Epoch 6/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.2776 - accuracy: 0.8882 - val_loss: 0.7871 - val_accuracy: 0.5556
# Epoch 7/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.2065 - accuracy: 0.9235 - val_loss: 0.8834 - val_accuracy: 0.5614
# Epoch 8/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.1263 - accuracy: 0.9603 - val_loss: 0.8037 - val_accuracy: 0.5906
# Epoch 9/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0829 - accuracy: 0.9853 - val_loss: 0.8377 - val_accuracy: 0.5965
# Epoch 10/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0443 - accuracy: 0.9971 - val_loss: 0.8505 - val_accuracy: 0.6316
# Epoch 11/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0339 - accuracy: 0.9941 - val_loss: 0.8934 - val_accuracy: 0.5906
# Epoch 12/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.8949 - val_accuracy: 0.5789
# Epoch 13/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.8482 - val_accuracy: 0.6023
# Epoch 14/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.9414 - val_accuracy: 0.6199
# Epoch 15/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.9175 - val_accuracy: 0.6199
# Epoch 16/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.0422 - val_accuracy: 0.6082
# Epoch 17/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.0277 - val_accuracy: 0.6199
# Epoch 18/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.0753 - val_accuracy: 0.6140
# Epoch 19/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.0573 - val_accuracy: 0.5965
# Epoch 20/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0907 - val_accuracy: 0.6023
# Epoch 21/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.0781 - val_accuracy: 0.6374
# Epoch 22/50
# 11/11 [==============================] - 0s 35ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0729 - val_accuracy: 0.6491
# Epoch 23/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0755 - val_accuracy: 0.6374
# Epoch 24/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.0631 - val_accuracy: 0.6257
# Epoch 25/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.0830 - val_accuracy: 0.6316
# Epoch 26/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0551 - val_accuracy: 0.6491
# Epoch 27/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0735 - val_accuracy: 0.6140
# Epoch 28/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.1006 - val_accuracy: 0.6374
# Epoch 29/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.1017 - val_accuracy: 0.6374
# Epoch 30/50
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.1187 - val_accuracy: 0.6257
# Epoch 31/50
# 11/11 [==============================] - 0s 33ms/step - loss: 7.9994e-04 - accuracy: 1.0000 - val_loss: 1.1623 - val_accuracy: 0.6257
# Epoch 32/50
# 11/11 [==============================] - 0s 33ms/step - loss: 9.0436e-04 - accuracy: 1.0000 - val_loss: 1.1402 - val_accuracy: 0.6491
# Epoch 33/50
# 11/11 [==============================] - 0s 33ms/step - loss: 9.3640e-04 - accuracy: 1.0000 - val_loss: 1.1671 - val_accuracy: 0.6374
# Epoch 34/50
# 11/11 [==============================] - 0s 33ms/step - loss: 6.7618e-04 - accuracy: 1.0000 - val_loss: 1.1656 - val_accuracy: 0.6316
# Epoch 35/50
# 11/11 [==============================] - 0s 33ms/step - loss: 5.6567e-04 - accuracy: 1.0000 - val_loss: 1.1832 - val_accuracy: 0.6374
# Epoch 36/50
# 11/11 [==============================] - 0s 33ms/step - loss: 5.0149e-04 - accuracy: 1.0000 - val_loss: 1.2031 - val_accuracy: 0.6316
# Epoch 37/50
# 11/11 [==============================] - 0s 33ms/step - loss: 4.9270e-04 - accuracy: 1.0000 - val_loss: 1.2238 - val_accuracy: 0.6316
# Epoch 38/50
# 11/11 [==============================] - 0s 33ms/step - loss: 4.3999e-04 - accuracy: 1.0000 - val_loss: 1.2391 - val_accuracy: 0.6374
# Epoch 39/50
# 11/11 [==============================] - 0s 33ms/step - loss: 4.5416e-04 - accuracy: 1.0000 - val_loss: 1.2522 - val_accuracy: 0.6374
# Epoch 40/50
# 11/11 [==============================] - 0s 33ms/step - loss: 4.6668e-04 - accuracy: 1.0000 - val_loss: 1.2622 - val_accuracy: 0.6374
# Epoch 41/50
# 11/11 [==============================] - 0s 33ms/step - loss: 4.7052e-04 - accuracy: 1.0000 - val_loss: 1.2767 - val_accuracy: 0.6316
# Epoch 42/50
# 11/11 [==============================] - 0s 33ms/step - loss: 3.6012e-04 - accuracy: 1.0000 - val_loss: 1.2873 - val_accuracy: 0.6316
# Epoch 43/50
# 11/11 [==============================] - 0s 33ms/step - loss: 3.5336e-04 - accuracy: 1.0000 - val_loss: 1.3023 - val_accuracy: 0.6316
# Epoch 44/50
# 11/11 [==============================] - 0s 34ms/step - loss: 5.0744e-04 - accuracy: 1.0000 - val_loss: 1.3173 - val_accuracy: 0.6316
# Epoch 45/50
# 11/11 [==============================] - 0s 33ms/step - loss: 3.9231e-04 - accuracy: 1.0000 - val_loss: 1.3531 - val_accuracy: 0.6316
# Epoch 46/50
# 11/11 [==============================] - 0s 33ms/step - loss: 3.2926e-04 - accuracy: 1.0000 - val_loss: 1.3592 - val_accuracy: 0.6316
# Epoch 47/50
# 11/11 [==============================] - 0s 32ms/step - loss: 3.1872e-04 - accuracy: 1.0000 - val_loss: 1.3570 - val_accuracy: 0.6316
# Epoch 48/50
# 11/11 [==============================] - 0s 32ms/step - loss: 2.9875e-04 - accuracy: 1.0000 - val_loss: 1.3635 - val_accuracy: 0.6374
# Epoch 49/50
# 11/11 [==============================] - 0s 33ms/step - loss: 3.3630e-04 - accuracy: 1.0000 - val_loss: 1.3724 - val_accuracy: 0.6374
# Epoch 50/50
# 11/11 [==============================] - 0s 32ms/step - loss: 3.4293e-04 - accuracy: 1.0000 - val_loss: 1.3576 - val_accuracy: 0.6491
# 9/9 - 0s - loss: 0.9722 - accuracy: 0.7782
#
# Test accuracy: 0.7781690359115601
# Sample: 1
# Predicted: BIRD?, Expected: BIRD!
# Sample: 2
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 3
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 4
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 5
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 6
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 7
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 8
# Predicted: BIRD?, Expected: BIRD!
# Sample: 9
# Predicted: BIRD?, Expected: BIRD!
# Sample: 10
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 11
# Predicted: BIRD?, Expected: BIRD!
# Sample: 12
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 13
# Predicted: BIRD?, Expected: BIRD!
# Sample: 14
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 15
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 16
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 17
# Predicted: BIRD?, Expected: BIRD!
# Sample: 18
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 19
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 20
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 21
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 22
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 23
# Predicted: BIRD?, Expected: BIRD!
# Sample: 24
# Predicted: BIRD?, Expected: BIRD!
# Sample: 25
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 26
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 27
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 28
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 29
# Predicted: BIRD?, Expected: BIRD!
# Sample: 30
# Predicted: BIRD?, Expected: BIRD!
# Sample: 31
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 32
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 33
# Predicted: BIRD?, Expected: BIRD!
# Sample: 34
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 35
# Predicted: BIRD?, Expected: BIRD!
# Sample: 36
# Predicted: BIRD?, Expected: BIRD!
# Sample: 37
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 38
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 39
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 40
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 41
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 42
# Predicted: BIRD?, Expected: BIRD!
# Sample: 43
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 44
# Predicted: BIRD?, Expected: BIRD!
# Sample: 45
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 46
# Predicted: BIRD?, Expected: BIRD!
# Sample: 47
# Predicted: BIRD?, Expected: BIRD!
# Sample: 48
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 49
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 50
# Predicted: BIRD?, Expected: BIRD!
# Sample: 51
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 52
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 53
# Predicted: BIRD?, Expected: BIRD!
# Sample: 54
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 55
# Predicted: BIRD?, Expected: BIRD!
# Sample: 56
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 57
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 58
# Predicted: BIRD?, Expected: BIRD!
# Sample: 59
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 60
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 61
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 62
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 63
# Predicted: BIRD?, Expected: BIRD!
# Sample: 64
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 65
# Predicted: BIRD?, Expected: BIRD!
# Sample: 66
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 67
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 68
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 69
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 70
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 71
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 72
# Predicted: BIRD?, Expected: BIRD!
# Sample: 73
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 74
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 75
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 76
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 77
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 78
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 79
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 80
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 81
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 82
# Predicted: BIRD?, Expected: BIRD!
# Sample: 83
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 84
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 85
# Predicted: BIRD?, Expected: BIRD!
# Sample: 86
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 87
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 88
# Predicted: BIRD?, Expected: BIRD!
# Sample: 89
# Predicted: BIRD?, Expected: BIRD!
# Sample: 90
# Predicted: BIRD?, Expected: BIRD!
# Sample: 91
# Predicted: BIRD?, Expected: BIRD!
# Sample: 92
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 93
# Predicted: BIRD?, Expected: BIRD!
# Sample: 94
# Predicted: BIRD?, Expected: BIRD!
# Sample: 95
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 96
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 97
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 98
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 99
# Predicted: BIRD?, Expected: BIRD!
# Sample: 100
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 101
# Predicted: BIRD?, Expected: BIRD!
# Sample: 102
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 103
# Predicted: BIRD?, Expected: BIRD!
# Sample: 104
# Predicted: BIRD?, Expected: BIRD!
# Sample: 105
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 106
# Predicted: BIRD?, Expected: BIRD!
# Sample: 107
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 108
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 109
# Predicted: BIRD?, Expected: BIRD!
# Sample: 110
# Predicted: BIRD?, Expected: BIRD!
# Sample: 111
# Predicted: BIRD?, Expected: BIRD!
# Sample: 112
# Predicted: BIRD?, Expected: BIRD!
# Sample: 113
# Predicted: BIRD?, Expected: BIRD!
# Sample: 114
# Predicted: BIRD?, Expected: BIRD!
# Sample: 115
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 116
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 117
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 118
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 119
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 120
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 121
# Predicted: BIRD?, Expected: BIRD!
# Sample: 122
# Predicted: BIRD?, Expected: BIRD!
# Sample: 123
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 124
# Predicted: BIRD?, Expected: BIRD!
# Sample: 125
# Predicted: BIRD?, Expected: BIRD!
# Sample: 126
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 127
# Predicted: BIRD?, Expected: BIRD!
# Sample: 128
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 129
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 130
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 131
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 132
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 133
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 134
# Predicted: BIRD?, Expected: BIRD!
# Sample: 135
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 136
# Predicted: BIRD?, Expected: BIRD!
# Sample: 137
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 138
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 139
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 140
# Predicted: BIRD?, Expected: BIRD!
# Sample: 141
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 142
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 143
# Predicted: BIRD?, Expected: BIRD!
# Sample: 144
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 145
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 146
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 147
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 148
# Predicted: BIRD?, Expected: BIRD!
# Sample: 149
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 150
# Predicted: BIRD?, Expected: BIRD!
# Sample: 151
# Predicted: BIRD?, Expected: BIRD!
# Sample: 152
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 153
# Predicted: BIRD?, Expected: BIRD!
# Sample: 154
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 155
# Predicted: BIRD?, Expected: BIRD!
# Sample: 156
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 157
# Predicted: BIRD?, Expected: BIRD!
# Sample: 158
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 159
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 160
# Predicted: BIRD?, Expected: BIRD!
# Sample: 161
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 162
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 163
# Predicted: BIRD?, Expected: BIRD!
# Sample: 164
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 165
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 166
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 167
# Predicted: BIRD?, Expected: BIRD!
# Sample: 168
# Predicted: BIRD?, Expected: BIRD!
# Sample: 169
# Predicted: BIRD?, Expected: BIRD!
# Sample: 170
# Predicted: BIRD?, Expected: BIRD!
# Sample: 171
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 172
# Predicted: BIRD?, Expected: BIRD!
# Sample: 173
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 174
# Predicted: BIRD?, Expected: BIRD!
# Sample: 175
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 176
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 177
# Predicted: BIRD?, Expected: BIRD!
# Sample: 178
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 179
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 180
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 181
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 182
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 183
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 184
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 185
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 186
# Predicted: BIRD?, Expected: BIRD!
# Sample: 187
# Predicted: BIRD?, Expected: BIRD!
# Sample: 188
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 189
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 190
# Predicted: BIRD?, Expected: BIRD!
# Sample: 191
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 192
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 193
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 194
# Predicted: BIRD?, Expected: BIRD!
# Sample: 195
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 196
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 197
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 198
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 199
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 200
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 201
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 202
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 203
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 204
# Predicted: BIRD?, Expected: BIRD!
# Sample: 205
# Predicted: BIRD?, Expected: BIRD!
# Sample: 206
# Predicted: BIRD?, Expected: BIRD!
# Sample: 207
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 208
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 209
# Predicted: BIRD?, Expected: BIRD!
# Sample: 210
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 211
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 212
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 213
# Predicted: BIRD?, Expected: BIRD!
# Sample: 214
# Predicted: BIRD?, Expected: BIRD!
# Sample: 215
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 216
# Predicted: BIRD?, Expected: BIRD!
# Sample: 217
# Predicted: BIRD?, Expected: BIRD!
# Sample: 218
# Predicted: BIRD?, Expected: BIRD!
# Sample: 219
# Predicted: BIRD?, Expected: BIRD!
# Sample: 220
# Predicted: BIRD?, Expected: BIRD!
# Sample: 221
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 222
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 223
# Predicted: BIRD?, Expected: BIRD!
# Sample: 224
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 225
# Predicted: BIRD?, Expected: BIRD!
# Sample: 226
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 227
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 228
# Predicted: BIRD?, Expected: BIRD!
# Sample: 229
# Predicted: BIRD?, Expected: BIRD!
# Sample: 230
# Predicted: BIRD?, Expected: BIRD!
# Sample: 231
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 232
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 233
# Predicted: BIRD?, Expected: BIRD!
# Sample: 234
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 235
# Predicted: BIRD?, Expected: BIRD!
# Sample: 236
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 237
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 238
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 239
# Predicted: BIRD?, Expected: BIRD!
# Sample: 240
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 241
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 242
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 243
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 244
# Predicted: BIRD?, Expected: BIRD!
# Sample: 245
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 246
# Predicted: BIRD?, Expected: BIRD!
# Sample: 247
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 248
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 249
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 250
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 251
# Predicted: BIRD?, Expected: BIRD!
# Sample: 252
# Predicted: BIRD?, Expected: BIRD!
# Sample: 253
# Predicted: BIRD?, Expected: BIRD!
# Sample: 254
# Predicted: BIRD?, Expected: BIRD!
# Sample: 255
# Predicted: BIRD?, Expected: BIRD!
# Sample: 256
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 257
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 258
# Predicted: BIRD?, Expected: BIRD!
# Sample: 259
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 260
# Predicted: BIRD?, Expected: BIRD!
# Sample: 261
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 262
# Predicted: BIRD?, Expected: BIRD!
# Sample: 263
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 264
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 265
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 266
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 267
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 268
# Predicted: BIRD?, Expected: BIRD!
# Sample: 269
# Predicted: BIRD?, Expected: BIRD!
# Sample: 270
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 271
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 272
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 273
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 274
# Predicted: BIRD?, Expected: BIRD!
# Sample: 275
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 276
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 277
# Predicted: BIRD?, Expected: BIRD!
# Sample: 278
# Predicted: BIRD?, Expected: NO BIRD!
# Sample: 279
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 280
# Predicted: BIRD?, Expected: BIRD!
# Sample: 281
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 282
# Predicted: NO BIRD?, Expected: BIRD!
# Sample: 283
# Predicted: NO BIRD?, Expected: NO BIRD!
# Sample: 284
# Predicted: BIRD?, Expected: NO BIRD!
