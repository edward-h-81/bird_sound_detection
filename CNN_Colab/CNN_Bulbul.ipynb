# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = '/content/drive/My Drive/MSc_Project_Colab/mixed_1140_1_segment_128_mels.json'


def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["log mel spectrogram"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates CNN model

    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 4th conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed to dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(256))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    # model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Dense(32))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.Dropout(0.5))


    # output layer
    model.add(keras.layers.Dense(1, activation='sigmoid'))

    return model


def predict(model, X, y):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    

    # # perform prediction
    # prediction = model.predict(X)

    # # get index with max value
    # predicted_index = np.argmax(prediction, axis=1)

    # if y == 0:
    #     dataLabel = "BIRD!"
    # else:
    #     dataLabel = "NO BIRD!"

    # if predicted_index == 0:
    #     myPrediction = "BIRD?"
    # else:
    #     myPrediction = "NO BIRD?"

    # print("Predicted: {}, Expected: {}".format(myPrediction, dataLabel))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.2, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.RMSprop(learning_rate=0.0005)
    model.compile(optimizer=optimiser,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=64, epochs=50)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # confusion matrix
    my_threshold = 0.5

    y_pred = (model.predict(X_test)>= my_threshold).astype(int)
    cm = confusion_matrix(y_test, y_pred)
    print(cm)

    # ROC
    # print("X_test pre ravel: {}".format(X_test.shape))
    y_preds = model.predict(X_test).ravel()
    # print("X_test post ravel: {}".format(X_test.shape))

    fpr, tpr, thresholds = roc_curve(y_test, y_preds)
    # print("fpr: {}, tpr: {}".format(fpr, tpr))
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'y--')
    plt.plot(fpr, tpr, marker='.')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.show

    # predict(model, X_test, y_test)

    # index = 0
    # # make prediction on a sample
    # while index < len(X_test):
    #     X = X_test[index]
    #     y = y_test[index]
    #     print("Sample: {}".format(index+1))
    #     predict(model, X, y)
    #     index += 1
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 429, 126, 16)      160
# _________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)   (None, 429, 126, 16)      0
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 215, 63, 16)       0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 215, 63, 16)       64
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 213, 61, 16)       2320
# _________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)   (None, 213, 61, 16)       0
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 107, 31, 16)       0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 107, 31, 16)       64
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 107, 29, 16)       784
# _________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)   (None, 107, 29, 16)       0
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 54, 15, 16)        0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 54, 15, 16)        64
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 54, 13, 16)        784
# _________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)   (None, 54, 13, 16)        0
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 27, 7, 16)         0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 27, 7, 16)         64
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 3024)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               774400
# _________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 32)                8224
# _________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 786,961
# Trainable params: 786,833
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/50
# 12/12 [==============================] - 2s 52ms/step - loss: 1.0530 - accuracy: 0.5565 - val_loss: 1.9363 - val_accuracy: 0.5879
# Epoch 2/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.7373 - accuracy: 0.6309 - val_loss: 1.7446 - val_accuracy: 0.5989
# Epoch 3/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.6316 - accuracy: 0.6887 - val_loss: 0.8045 - val_accuracy: 0.6374
# Epoch 4/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4616 - accuracy: 0.7934 - val_loss: 0.7830 - val_accuracy: 0.6758
# Epoch 5/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.4197 - accuracy: 0.8085 - val_loss: 0.8127 - val_accuracy: 0.6319
# Epoch 6/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.3720 - accuracy: 0.8264 - val_loss: 0.7595 - val_accuracy: 0.6538
# Epoch 7/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.2715 - accuracy: 0.8802 - val_loss: 0.6615 - val_accuracy: 0.6813
# Epoch 8/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.2098 - accuracy: 0.9201 - val_loss: 1.1157 - val_accuracy: 0.6099
# Epoch 9/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.1914 - accuracy: 0.9201 - val_loss: 0.7896 - val_accuracy: 0.6319
# Epoch 10/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.1687 - accuracy: 0.9408 - val_loss: 1.0678 - val_accuracy: 0.6374
# Epoch 11/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.1022 - accuracy: 0.9683 - val_loss: 0.9600 - val_accuracy: 0.6593
# Epoch 12/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.1598 - accuracy: 0.9477 - val_loss: 0.8861 - val_accuracy: 0.6044
# Epoch 13/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0822 - accuracy: 0.9738 - val_loss: 1.0562 - val_accuracy: 0.6374
# Epoch 14/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0450 - accuracy: 0.9862 - val_loss: 1.1546 - val_accuracy: 0.6374
# Epoch 15/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0313 - accuracy: 0.9945 - val_loss: 1.3437 - val_accuracy: 0.5604
# Epoch 16/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0920 - accuracy: 0.9711 - val_loss: 1.3257 - val_accuracy: 0.6868
# Epoch 17/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0409 - accuracy: 0.9876 - val_loss: 1.0461 - val_accuracy: 0.6374
# Epoch 18/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0154 - accuracy: 0.9986 - val_loss: 1.2288 - val_accuracy: 0.6484
# Epoch 19/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0261 - accuracy: 0.9917 - val_loss: 1.2679 - val_accuracy: 0.6703
# Epoch 20/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0151 - accuracy: 0.9945 - val_loss: 1.2923 - val_accuracy: 0.6484
# Epoch 21/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.1718 - accuracy: 0.9587 - val_loss: 1.3340 - val_accuracy: 0.6429
# Epoch 22/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0133 - accuracy: 0.9986 - val_loss: 1.5076 - val_accuracy: 0.6813
# Epoch 23/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.3535 - val_accuracy: 0.7033
# Epoch 24/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0523 - accuracy: 0.9807 - val_loss: 1.6701 - val_accuracy: 0.6648
# Epoch 25/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0178 - accuracy: 0.9945 - val_loss: 1.6688 - val_accuracy: 0.6374
# Epoch 26/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0146 - accuracy: 0.9959 - val_loss: 1.5350 - val_accuracy: 0.6868
# Epoch 27/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0354 - accuracy: 0.9876 - val_loss: 2.5130 - val_accuracy: 0.5769
# Epoch 28/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0904 - accuracy: 0.9848 - val_loss: 1.9707 - val_accuracy: 0.6703
# Epoch 29/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.8675 - val_accuracy: 0.7088
# Epoch 30/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 2.1211 - val_accuracy: 0.5824
# Epoch 31/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 2.0440 - val_accuracy: 0.6484
# Epoch 32/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0359 - accuracy: 0.9890 - val_loss: 2.1587 - val_accuracy: 0.6209
# Epoch 33/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0330 - accuracy: 0.9890 - val_loss: 2.3967 - val_accuracy: 0.5879
# Epoch 34/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0112 - accuracy: 0.9972 - val_loss: 2.3728 - val_accuracy: 0.5769
# Epoch 35/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 2.3923 - val_accuracy: 0.5934
# Epoch 36/50
# 12/12 [==============================] - 0s 34ms/step - loss: 8.5482e-04 - accuracy: 1.0000 - val_loss: 2.4067 - val_accuracy: 0.5879
# Epoch 37/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0462 - accuracy: 0.9904 - val_loss: 2.5360 - val_accuracy: 0.5659
# Epoch 38/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0059 - accuracy: 0.9972 - val_loss: 2.4184 - val_accuracy: 0.5934
# Epoch 39/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0201 - accuracy: 0.9917 - val_loss: 2.6546 - val_accuracy: 0.6264
# Epoch 40/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0248 - accuracy: 0.9972 - val_loss: 3.4574 - val_accuracy: 0.6538
# Epoch 41/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 2.6543 - val_accuracy: 0.6319
# Epoch 42/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 2.9003 - val_accuracy: 0.6429
# Epoch 43/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 2.6122 - val_accuracy: 0.6044
# Epoch 44/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0259 - accuracy: 0.9904 - val_loss: 2.6976 - val_accuracy: 0.6319
# Epoch 45/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 2.7452 - val_accuracy: 0.6264
# Epoch 46/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0240 - accuracy: 0.9945 - val_loss: 2.8384 - val_accuracy: 0.6154
# Epoch 47/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0200 - accuracy: 0.9904 - val_loss: 2.8601 - val_accuracy: 0.6209
# Epoch 48/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0230 - accuracy: 0.9972 - val_loss: 3.0526 - val_accuracy: 0.5989
# Epoch 49/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0175 - accuracy: 0.9917 - val_loss: 2.9152 - val_accuracy: 0.5989
# Epoch 50/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0091 - accuracy: 0.9986 - val_loss: 3.0840 - val_accuracy: 0.5714
# 8/8 - 0s - loss: 3.0330 - accuracy: 0.6256
#
# Test accuracy: 0.6255506873130798
# [[69 47]
#  [38 73]]
