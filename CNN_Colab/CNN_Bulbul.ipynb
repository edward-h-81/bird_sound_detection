# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = '/content/drive/My Drive/MSc_Project_Colab/mixed_1140_1_segment_128_mels.json'


def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["log mel spectrogram"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train acc")
    axs[0].plot(history.history["val_accuracy"], label="val acc")
    axs[0].set_ylabel("Accuracy")
    axs[1].set_xlabel("Epoch")
    axs[0].legend(loc="lower right")
    # axs[0].set_title("Accuracy")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train loss")
    axs[1].plot(history.history["val_loss"], label="val loss")
    axs[1].set_ylabel("Loss")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    # axs[1].set_title("Loss")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=2)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size, random_state=2)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates CNN model

    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 4th conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed to dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(256))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    # model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Dense(32))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    # model.add(keras.layers.Dropout(0.4))


    # output layer
    model.add(keras.layers.Dense(1, activation='sigmoid'))

    return model


def predict(model, X, y):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    

    # # perform prediction
    # prediction = model.predict(X)

    # # get index with max value
    # predicted_index = np.argmax(prediction, axis=1)

    # if y == 0:
    #     dataLabel = "BIRD!"
    # else:
    #     dataLabel = "NO BIRD!"

    # if predicted_index == 0:
    #     myPrediction = "BIRD?"
    # else:
    #     myPrediction = "NO BIRD?"

    # print("Predicted: {}, Expected: {}".format(myPrediction, dataLabel))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.2, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimiser,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=64, epochs=50)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # confusion matrix
    my_threshold = 0.5

    y_pred = (model.predict(X_test)>= my_threshold).astype(int)
    cm = confusion_matrix(y_test, y_pred)
    print(cm)

    # ROC
    # print("X_test pre ravel: {}".format(X_test.shape))
    y_preds = model.predict(X_test).ravel()
    # print("X_test post ravel: {}".format(X_test.shape))

    fpr, tpr, thresholds = roc_curve(y_test, y_preds)
    # print("fpr: {}, tpr: {}".format(fpr, tpr))
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'y--')
    plt.plot(fpr, tpr, marker='.')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.show

    #One way to find the best threshold once we calculate the true positive 
    # and false positive rates is ...
    # The optimal cut off point would be where “true positive rate” is high 
    # and the “false positive rate” is low. 
    # Based on this logic let us find the threshold where tpr-(1-fpr) is zero (or close to 0)
    
    import pandas as pd
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'tf' : pd.Series(tpr-(1-fpr), index=i), 'thresholds' : pd.Series(thresholds, index=i)})
    ideal_roc_thresh = roc.iloc[(roc.tf-0).abs().argsort()[:1]]  #Locate the point where the value is close to 0
    print("Ideal threshold is: ", ideal_roc_thresh['thresholds']) 

    #Now use this threshold value in the confusion matrix to visualize the balance
    #between tp, fp, fp, and fn

    # AUC
    from sklearn.metrics import auc
    auc_value = auc(fpr, tpr)
    print("Area under curve, AUC = ", auc_value)

    # predict(model, X_test, y_test)

    # index = 0
    # # make prediction on a sample
    # while index < len(X_test):
    #     X = X_test[index]
    #     y = y_test[index]
    #     print("Sample: {}".format(index+1))
    #     predict(model, X, y)
    #     index += 1
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_40 (Conv2D)           (None, 429, 126, 16)      160
# _________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)   (None, 429, 126, 16)      0
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 215, 63, 16)       0
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 215, 63, 16)       64
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 213, 61, 16)       2320
# _________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)   (None, 213, 61, 16)       0
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 107, 31, 16)       0
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 107, 31, 16)       64
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 107, 29, 16)       784
# _________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)   (None, 107, 29, 16)       0
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 54, 15, 16)        0
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 54, 15, 16)        64
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 54, 13, 16)        784
# _________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)   (None, 54, 13, 16)        0
# _________________________________________________________________
# max_pooling2d_43 (MaxPooling (None, 27, 7, 16)         0
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 27, 7, 16)         64
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 3024)              0
# _________________________________________________________________
# dense_30 (Dense)             (None, 256)               774400
# _________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 32)                8224
# _________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 786,961
# Trainable params: 786,833
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/50
# 12/12 [==============================] - 1s 53ms/step - loss: 0.9449 - accuracy: 0.5950 - val_loss: 2.8235 - val_accuracy: 0.5275
# Epoch 2/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.5610 - accuracy: 0.7383 - val_loss: 0.7703 - val_accuracy: 0.5330
# Epoch 3/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.4670 - accuracy: 0.7755 - val_loss: 0.9575 - val_accuracy: 0.5659
# Epoch 4/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.3241 - accuracy: 0.8650 - val_loss: 0.7270 - val_accuracy: 0.5659
# Epoch 5/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.2475 - accuracy: 0.8926 - val_loss: 0.8616 - val_accuracy: 0.5495
# Epoch 6/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.1819 - accuracy: 0.9394 - val_loss: 0.8012 - val_accuracy: 0.5495
# Epoch 7/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.1175 - accuracy: 0.9683 - val_loss: 0.8311 - val_accuracy: 0.5824
# Epoch 8/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0884 - accuracy: 0.9697 - val_loss: 0.8647 - val_accuracy: 0.5110
# Epoch 9/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0450 - accuracy: 0.9972 - val_loss: 0.9197 - val_accuracy: 0.6044
# Epoch 10/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.9749 - val_accuracy: 0.5714
# Epoch 11/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0149 - accuracy: 0.9986 - val_loss: 1.0424 - val_accuracy: 0.5934
# Epoch 12/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 1.0815 - val_accuracy: 0.5714
# Epoch 13/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.0201 - val_accuracy: 0.5714
# Epoch 14/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.0715 - val_accuracy: 0.5934
# Epoch 15/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.0260 - val_accuracy: 0.6154
# Epoch 16/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.1373 - val_accuracy: 0.6154
# Epoch 17/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.0739 - val_accuracy: 0.6154
# Epoch 18/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0594 - val_accuracy: 0.6538
# Epoch 19/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0952 - val_accuracy: 0.6484
# Epoch 20/50
# 12/12 [==============================] - 0s 35ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.0751 - val_accuracy: 0.6648
# Epoch 21/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.0713 - val_accuracy: 0.6703
# Epoch 22/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.1181 - val_accuracy: 0.6484
# Epoch 23/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.1075 - val_accuracy: 0.6648
# Epoch 24/50
# 12/12 [==============================] - 0s 36ms/step - loss: 9.1986e-04 - accuracy: 1.0000 - val_loss: 1.1184 - val_accuracy: 0.6648
# Epoch 25/50
# 12/12 [==============================] - 0s 36ms/step - loss: 8.4565e-04 - accuracy: 1.0000 - val_loss: 1.1476 - val_accuracy: 0.6648
# Epoch 26/50
# 12/12 [==============================] - 0s 36ms/step - loss: 7.7635e-04 - accuracy: 1.0000 - val_loss: 1.1548 - val_accuracy: 0.6648
# Epoch 27/50
# 12/12 [==============================] - 0s 38ms/step - loss: 7.6551e-04 - accuracy: 1.0000 - val_loss: 1.1658 - val_accuracy: 0.6648
# Epoch 28/50
# 12/12 [==============================] - 0s 35ms/step - loss: 6.9830e-04 - accuracy: 1.0000 - val_loss: 1.1869 - val_accuracy: 0.6648
# Epoch 29/50
# 12/12 [==============================] - 0s 36ms/step - loss: 6.7691e-04 - accuracy: 1.0000 - val_loss: 1.2030 - val_accuracy: 0.6538
# Epoch 30/50
# 12/12 [==============================] - 0s 35ms/step - loss: 7.7739e-04 - accuracy: 1.0000 - val_loss: 1.2124 - val_accuracy: 0.6538
# Epoch 31/50
# 12/12 [==============================] - 0s 36ms/step - loss: 5.5198e-04 - accuracy: 1.0000 - val_loss: 1.2245 - val_accuracy: 0.6703
# Epoch 32/50
# 12/12 [==============================] - 0s 36ms/step - loss: 5.1735e-04 - accuracy: 1.0000 - val_loss: 1.2281 - val_accuracy: 0.6648
# Epoch 33/50
# 12/12 [==============================] - 0s 36ms/step - loss: 5.5859e-04 - accuracy: 1.0000 - val_loss: 1.2459 - val_accuracy: 0.6538
# Epoch 34/50
# 12/12 [==============================] - 0s 35ms/step - loss: 4.3401e-04 - accuracy: 1.0000 - val_loss: 1.2578 - val_accuracy: 0.6484
# Epoch 35/50
# 12/12 [==============================] - 0s 35ms/step - loss: 4.9416e-04 - accuracy: 1.0000 - val_loss: 1.2677 - val_accuracy: 0.6593
# Epoch 36/50
# 12/12 [==============================] - 0s 35ms/step - loss: 4.3584e-04 - accuracy: 1.0000 - val_loss: 1.2825 - val_accuracy: 0.6538
# Epoch 37/50
# 12/12 [==============================] - 0s 36ms/step - loss: 4.9356e-04 - accuracy: 1.0000 - val_loss: 1.3040 - val_accuracy: 0.6484
# Epoch 38/50
# 12/12 [==============================] - 0s 36ms/step - loss: 4.0860e-04 - accuracy: 1.0000 - val_loss: 1.3031 - val_accuracy: 0.6703
# Epoch 39/50
# 12/12 [==============================] - 0s 35ms/step - loss: 3.7584e-04 - accuracy: 1.0000 - val_loss: 1.3158 - val_accuracy: 0.6593
# Epoch 40/50
# 12/12 [==============================] - 0s 35ms/step - loss: 3.5686e-04 - accuracy: 1.0000 - val_loss: 1.3240 - val_accuracy: 0.6538
# Epoch 41/50
# 12/12 [==============================] - 0s 35ms/step - loss: 3.6849e-04 - accuracy: 1.0000 - val_loss: 1.3334 - val_accuracy: 0.6703
# Epoch 42/50
# 12/12 [==============================] - 0s 35ms/step - loss: 3.5793e-04 - accuracy: 1.0000 - val_loss: 1.3437 - val_accuracy: 0.6758
# Epoch 43/50
# 12/12 [==============================] - 0s 35ms/step - loss: 3.3457e-04 - accuracy: 1.0000 - val_loss: 1.3455 - val_accuracy: 0.6703
# Epoch 44/50
# 12/12 [==============================] - 0s 34ms/step - loss: 2.7293e-04 - accuracy: 1.0000 - val_loss: 1.3531 - val_accuracy: 0.6648
# Epoch 45/50
# 12/12 [==============================] - 0s 35ms/step - loss: 2.8411e-04 - accuracy: 1.0000 - val_loss: 1.3625 - val_accuracy: 0.6703
# Epoch 46/50
# 12/12 [==============================] - 0s 35ms/step - loss: 3.0517e-04 - accuracy: 1.0000 - val_loss: 1.3799 - val_accuracy: 0.6703
# Epoch 47/50
# 12/12 [==============================] - 0s 35ms/step - loss: 4.5641e-04 - accuracy: 1.0000 - val_loss: 1.4159 - val_accuracy: 0.6703
# Epoch 48/50
# 12/12 [==============================] - 0s 34ms/step - loss: 7.2937e-04 - accuracy: 1.0000 - val_loss: 1.4862 - val_accuracy: 0.6703
# Epoch 49/50
# 12/12 [==============================] - 0s 35ms/step - loss: 4.6752e-04 - accuracy: 1.0000 - val_loss: 1.4058 - val_accuracy: 0.6593
# Epoch 50/50
# 12/12 [==============================] - 0s 35ms/step - loss: 4.8031e-04 - accuracy: 1.0000 - val_loss: 1.4245 - val_accuracy: 0.6648
# 8/8 - 0s - loss: 1.3990 - accuracy: 0.6960
#
# Test accuracy: 0.6960352659225464
# [[76 39]
#  [30 82]]
# Ideal threshold is:  45    0.66047
# Name: thresholds, dtype: float32
# Area under curve, AUC =  0.7361801242236025
