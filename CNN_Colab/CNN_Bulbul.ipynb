# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = '/content/drive/My Drive/MSc_Project_Colab/mixed_1140_1_segment_128_mels.json'


def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["log mel spectrogram"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates CNN model

    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 4th conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed to dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(256))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    # model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Dense(32))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.Dropout(0.5))


    # output layer
    model.add(keras.layers.Dense(1, activation='sigmoid'))

    return model


def predict(model, X, y):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    

    # # perform prediction
    # prediction = model.predict(X)

    # # get index with max value
    # predicted_index = np.argmax(prediction, axis=1)

    # if y == 0:
    #     dataLabel = "BIRD!"
    # else:
    #     dataLabel = "NO BIRD!"

    # if predicted_index == 0:
    #     myPrediction = "BIRD?"
    # else:
    #     myPrediction = "NO BIRD?"

    # print("Predicted: {}, Expected: {}".format(myPrediction, dataLabel))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.2, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0005)
    model.compile(optimizer=optimiser,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=64, epochs=50)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # confusion matrix
    my_threshold = 0.5

    y_pred = (model.predict(X_test)>= my_threshold).astype(int)
    cm = confusion_matrix(y_test, y_pred)
    print(cm)

    # ROC
    # print("X_test pre ravel: {}".format(X_test.shape))
    y_preds = model.predict(X_test).ravel()
    # print("X_test post ravel: {}".format(X_test.shape))

    fpr, tpr, thresholds = roc_curve(y_test, y_preds)
    # print("fpr: {}, tpr: {}".format(fpr, tpr))
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'y--')
    plt.plot(fpr, tpr, marker='.')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.show

    # predict(model, X_test, y_test)

    # index = 0
    # # make prediction on a sample
    # while index < len(X_test):
    #     X = X_test[index]
    #     y = y_test[index]
    #     print("Sample: {}".format(index+1))
    #     predict(model, X, y)
    #     index += 1
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_28 (Conv2D)           (None, 429, 126, 16)      160
# _________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)   (None, 429, 126, 16)      0
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 215, 63, 16)       0
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 215, 63, 16)       64
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 213, 61, 16)       2320
# _________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)   (None, 213, 61, 16)       0
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 107, 31, 16)       0
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 107, 31, 16)       64
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 107, 29, 16)       784
# _________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)   (None, 107, 29, 16)       0
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 54, 15, 16)        0
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 54, 15, 16)        64
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 54, 13, 16)        784
# _________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)   (None, 54, 13, 16)        0
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 27, 7, 16)         0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 27, 7, 16)         64
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 3024)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               774400
# _________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 32)                8224
# _________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 786,961
# Trainable params: 786,833
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/50
# 12/12 [==============================] - 1s 49ms/step - loss: 1.0202 - accuracy: 0.5455 - val_loss: 0.8817 - val_accuracy: 0.4725
# Epoch 2/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.7755 - accuracy: 0.6033 - val_loss: 0.8298 - val_accuracy: 0.5000
# Epoch 3/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.6057 - accuracy: 0.7218 - val_loss: 1.0327 - val_accuracy: 0.5000
# Epoch 4/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.5310 - accuracy: 0.7438 - val_loss: 0.8815 - val_accuracy: 0.5220
# Epoch 5/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.4967 - accuracy: 0.7686 - val_loss: 0.7472 - val_accuracy: 0.5769
# Epoch 6/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.4657 - accuracy: 0.7893 - val_loss: 0.7254 - val_accuracy: 0.5549
# Epoch 7/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.4310 - accuracy: 0.7893 - val_loss: 0.8377 - val_accuracy: 0.5385
# Epoch 8/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.4002 - accuracy: 0.8196 - val_loss: 0.7826 - val_accuracy: 0.5769
# Epoch 9/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.2983 - accuracy: 0.8678 - val_loss: 0.8222 - val_accuracy: 0.5769
# Epoch 10/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.2623 - accuracy: 0.8953 - val_loss: 0.8922 - val_accuracy: 0.5769
# Epoch 11/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.2285 - accuracy: 0.9118 - val_loss: 0.8131 - val_accuracy: 0.5989
# Epoch 12/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.1782 - accuracy: 0.9270 - val_loss: 0.8598 - val_accuracy: 0.6099
# Epoch 13/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.1268 - accuracy: 0.9559 - val_loss: 0.7529 - val_accuracy: 0.6593
# Epoch 14/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.1368 - accuracy: 0.9449 - val_loss: 0.7543 - val_accuracy: 0.6154
# Epoch 15/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.1008 - accuracy: 0.9642 - val_loss: 0.8400 - val_accuracy: 0.6374
# Epoch 16/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0869 - accuracy: 0.9683 - val_loss: 0.7084 - val_accuracy: 0.6484
# Epoch 17/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0920 - accuracy: 0.9683 - val_loss: 0.8987 - val_accuracy: 0.5989
# Epoch 18/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0541 - accuracy: 0.9876 - val_loss: 0.8407 - val_accuracy: 0.6648
# Epoch 19/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0536 - accuracy: 0.9862 - val_loss: 0.8264 - val_accuracy: 0.6758
# Epoch 20/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0287 - accuracy: 0.9945 - val_loss: 0.9452 - val_accuracy: 0.6484
# Epoch 21/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0252 - accuracy: 0.9986 - val_loss: 0.9176 - val_accuracy: 0.6484
# Epoch 22/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.9951 - val_accuracy: 0.6374
# Epoch 23/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0209 - accuracy: 0.9972 - val_loss: 0.9610 - val_accuracy: 0.6868
# Epoch 24/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 1.1821 - val_accuracy: 0.6868
# Epoch 25/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 1.1244 - val_accuracy: 0.6868
# Epoch 26/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0123 - accuracy: 0.9986 - val_loss: 1.1664 - val_accuracy: 0.7143
# Epoch 27/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0138 - accuracy: 0.9986 - val_loss: 1.1489 - val_accuracy: 0.6758
# Epoch 28/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0123 - accuracy: 0.9986 - val_loss: 1.1986 - val_accuracy: 0.6923
# Epoch 29/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.2758 - val_accuracy: 0.7033
# Epoch 30/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0116 - accuracy: 0.9972 - val_loss: 1.3405 - val_accuracy: 0.6923
# Epoch 31/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0075 - accuracy: 0.9986 - val_loss: 1.1998 - val_accuracy: 0.6978
# Epoch 32/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.3087 - val_accuracy: 0.7308
# Epoch 33/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.2978 - val_accuracy: 0.7033
# Epoch 34/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.4156 - val_accuracy: 0.6813
# Epoch 35/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.4428 - val_accuracy: 0.6868
# Epoch 36/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.5224 - val_accuracy: 0.6703
# Epoch 37/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.4988 - val_accuracy: 0.6923
# Epoch 38/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.4689 - val_accuracy: 0.7088
# Epoch 39/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.4863 - val_accuracy: 0.6923
# Epoch 40/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.5478 - val_accuracy: 0.6868
# Epoch 41/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.5425 - val_accuracy: 0.6923
# Epoch 42/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.5481 - val_accuracy: 0.6923
# Epoch 43/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.6148 - val_accuracy: 0.6868
# Epoch 44/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.6236 - val_accuracy: 0.7033
# Epoch 45/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 1.5875 - val_accuracy: 0.7033
# Epoch 46/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.5689 - val_accuracy: 0.7033
# Epoch 47/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.5906 - val_accuracy: 0.6868
# Epoch 48/50
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.6858 - val_accuracy: 0.6923
# Epoch 49/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.7440 - val_accuracy: 0.6868
# Epoch 50/50
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.7232 - val_accuracy: 0.6868
# 8/8 - 0s - loss: 1.8135 - accuracy: 0.6432
#
# Test accuracy: 0.6431717872619629
# [[74 36]
#  [45 72]]
