# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import roc_curve
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import pandas as pd

DATA_PATH = '/content/drive/My Drive/MSc_Project_Colab/mixed_114_32mels_filenames.json'


def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["log mel spectrogram"])
    y = np.array(data["labels"])
    z = np.array(data["filenames"])
    return X, y, z


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train acc")
    axs[0].plot(history.history["val_accuracy"], label="val acc")
    axs[0].set_ylabel("Accuracy")
    axs[1].set_xlabel("Epoch")
    axs[0].legend(loc="lower right")
    # axs[0].set_title("Accuracy")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train loss")
    axs[1].plot(history.history["val_loss"], label="val loss")
    axs[1].set_ylabel("Loss")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    # axs[1].set_title("Loss")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y, z = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test, z_train, z_test = train_test_split(X, y, z, test_size=test_size, random_state=1)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size, random_state=1)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test, z_train, z_test


def build_model(input_shape):
    """Generates CNN model

    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 4th conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed to dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(256))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    # model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Dense(32))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    # model.add(keras.layers.Dropout(0.4))


    # output layer
    model.add(keras.layers.Dense(1, activation='sigmoid'))

    return model


def predict(model, X, y, z):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    

    # perform prediction
    prediction = model.predict(X)

    print("Probability: {}".format(model.predict(X)))

    thresh = 0.5

    if  y == 0:
        dataLabel = "BIRD!"
    else:
        dataLabel = "NO BIRD!"

    if model.predict(X)<= thresh:
        myPrediction = "BIRD?"
    else:
        myPrediction = "NO BIRD?"

    print("Predicted: {}, Expected: {}, File: {}".format(myPrediction, dataLabel, z))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test, z_train, z_test = prepare_datasets(0.2, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimiser,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=64, epochs=50)

    # plot accuracy/error for training and validation
    plot_history(history)

    
    # make prediction on a sample
    for index in range(int(len(X_test) / 10)):
        X = X_test[index]
        y = y_test[index]
        z = z_test[index]
        print("Sample: {}".format(index+1))
        predict(model, X, y, z)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # ROC
    # print("X_test pre ravel: {}".format(X_test.shape))
    y_preds = model.predict(X_test).ravel()
    # print("X_test post ravel: {}".format(X_test.shape))

    fpr, tpr, thresholds = roc_curve(y_test, y_preds)
    # print("fpr: {}, tpr: {}".format(fpr, tpr))
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'y--')
    plt.plot(fpr, tpr, marker='.')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.show

    #One way to find the best threshold once we calculate the true positive 
    # and false positive rates is ...
    # The optimal cut off point would be where “true positive rate” is high 
    # and the “false positive rate” is low. 
    # Based on this logic let us find the threshold where tpr-(1-fpr) is zero (or close to 0)
    
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'tf' : pd.Series(tpr-(1-fpr), index=i), 'thresholds' : pd.Series(thresholds, index=i)})
    ideal_roc_thresh = roc.iloc[(roc.tf-0).abs().argsort()[:1]]  #Locate the point where the value is close to 0
    print("Ideal threshold is: ", ideal_roc_thresh['thresholds']) 

    #Now use this threshold value in the confusion matrix to visualize the balance
    #between tp, fp, fp, and fn

    # AUC
    from sklearn.metrics import auc
    auc_value = auc(fpr, tpr)
    print("Area under curve, AUC = ", auc_value)

    # confusion matrix
    my_threshold = 0.5

    y_pred = (model.predict(X_test)>= my_threshold).astype(int)
    cm = confusion_matrix(y_test, y_pred)
    # print(cm)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["bird", "no bird"])
    disp.plot()
# Out:
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_120 (Conv2D)          (None, 429, 30, 16)       160
# _________________________________________________________________
# leaky_re_lu_180 (LeakyReLU)  (None, 429, 30, 16)       0
# _________________________________________________________________
# max_pooling2d_120 (MaxPoolin (None, 215, 15, 16)       0
# _________________________________________________________________
# batch_normalization_120 (Bat (None, 215, 15, 16)       64
# _________________________________________________________________
# conv2d_121 (Conv2D)          (None, 213, 13, 16)       2320
# _________________________________________________________________
# leaky_re_lu_181 (LeakyReLU)  (None, 213, 13, 16)       0
# _________________________________________________________________
# max_pooling2d_121 (MaxPoolin (None, 107, 7, 16)        0
# _________________________________________________________________
# batch_normalization_121 (Bat (None, 107, 7, 16)        64
# _________________________________________________________________
# conv2d_122 (Conv2D)          (None, 107, 5, 16)        784
# _________________________________________________________________
# leaky_re_lu_182 (LeakyReLU)  (None, 107, 5, 16)        0
# _________________________________________________________________
# max_pooling2d_122 (MaxPoolin (None, 54, 3, 16)         0
# _________________________________________________________________
# batch_normalization_122 (Bat (None, 54, 3, 16)         64
# _________________________________________________________________
# conv2d_123 (Conv2D)          (None, 54, 1, 16)         784
# _________________________________________________________________
# leaky_re_lu_183 (LeakyReLU)  (None, 54, 1, 16)         0
# _________________________________________________________________
# max_pooling2d_123 (MaxPoolin (None, 27, 1, 16)         0
# _________________________________________________________________
# batch_normalization_123 (Bat (None, 27, 1, 16)         64
# _________________________________________________________________
# flatten_30 (Flatten)         (None, 432)               0
# _________________________________________________________________
# dense_90 (Dense)             (None, 256)               110848
# _________________________________________________________________
# leaky_re_lu_184 (LeakyReLU)  (None, 256)               0
# _________________________________________________________________
# dense_91 (Dense)             (None, 32)                8224
# _________________________________________________________________
# leaky_re_lu_185 (LeakyReLU)  (None, 32)                0
# _________________________________________________________________
# dense_92 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 123,409
# Trainable params: 123,281
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/50
# 2/2 [==============================] - 1s 248ms/step - loss: 0.8984 - accuracy: 0.4583 - val_loss: 4.0373 - val_accuracy: 0.2632
# Epoch 2/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5661 - accuracy: 0.6667 - val_loss: 3.1760 - val_accuracy: 0.2632
# Epoch 3/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4207 - accuracy: 0.8333 - val_loss: 2.3396 - val_accuracy: 0.2632
# Epoch 4/50
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3626 - accuracy: 0.8472 - val_loss: 2.1312 - val_accuracy: 0.2632
# Epoch 5/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3179 - accuracy: 0.8889 - val_loss: 2.5396 - val_accuracy: 0.2632
# Epoch 6/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2697 - accuracy: 0.9167 - val_loss: 2.7399 - val_accuracy: 0.2632
# Epoch 7/50
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2486 - accuracy: 0.9306 - val_loss: 2.5013 - val_accuracy: 0.2632
# Epoch 8/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2193 - accuracy: 0.9444 - val_loss: 2.2015 - val_accuracy: 0.3158
# Epoch 9/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1727 - accuracy: 0.9861 - val_loss: 2.1292 - val_accuracy: 0.3158
# Epoch 10/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1629 - accuracy: 0.9861 - val_loss: 2.2375 - val_accuracy: 0.3158
# Epoch 11/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1506 - accuracy: 1.0000 - val_loss: 2.2925 - val_accuracy: 0.3158
# Epoch 12/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1268 - accuracy: 1.0000 - val_loss: 2.2877 - val_accuracy: 0.3158
# Epoch 13/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0996 - accuracy: 1.0000 - val_loss: 2.3647 - val_accuracy: 0.3158
# Epoch 14/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0837 - accuracy: 1.0000 - val_loss: 2.4320 - val_accuracy: 0.2632
# Epoch 15/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0729 - accuracy: 1.0000 - val_loss: 2.4699 - val_accuracy: 0.2632
# Epoch 16/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0709 - accuracy: 1.0000 - val_loss: 2.5087 - val_accuracy: 0.2632
# Epoch 17/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0588 - accuracy: 1.0000 - val_loss: 2.4654 - val_accuracy: 0.3158
# Epoch 18/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0525 - accuracy: 1.0000 - val_loss: 2.4038 - val_accuracy: 0.3158
# Epoch 19/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0444 - accuracy: 1.0000 - val_loss: 2.4254 - val_accuracy: 0.3158
# Epoch 20/50
# 2/2 [==============================] - 0s 39ms/step - loss: 0.0343 - accuracy: 1.0000 - val_loss: 2.4346 - val_accuracy: 0.3158
# Epoch 21/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0338 - accuracy: 1.0000 - val_loss: 2.3949 - val_accuracy: 0.3158
# Epoch 22/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0316 - accuracy: 1.0000 - val_loss: 2.2827 - val_accuracy: 0.3158
# Epoch 23/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 2.2206 - val_accuracy: 0.3158
# Epoch 24/50
# 2/2 [==============================] - 0s 42ms/step - loss: 0.0301 - accuracy: 1.0000 - val_loss: 2.2177 - val_accuracy: 0.3158
# Epoch 25/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 2.1994 - val_accuracy: 0.3158
# Epoch 26/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 2.1385 - val_accuracy: 0.3158
# Epoch 27/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 2.0333 - val_accuracy: 0.3158
# Epoch 28/50
# 2/2 [==============================] - 0s 36ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 1.9305 - val_accuracy: 0.3158
# Epoch 29/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 1.8559 - val_accuracy: 0.3158
# Epoch 30/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 1.7967 - val_accuracy: 0.3158
# Epoch 31/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 1.7667 - val_accuracy: 0.3158
# Epoch 32/50
# 2/2 [==============================] - 0s 35ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 1.7721 - val_accuracy: 0.2632
# Epoch 33/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.8081 - val_accuracy: 0.2632
# Epoch 34/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.8676 - val_accuracy: 0.2632
# Epoch 35/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.9090 - val_accuracy: 0.2632
# Epoch 36/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.9324 - val_accuracy: 0.2632
# Epoch 37/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.9576 - val_accuracy: 0.2632
# Epoch 38/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.9259 - val_accuracy: 0.3158
# Epoch 39/50
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.8898 - val_accuracy: 0.3158
# Epoch 40/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.8395 - val_accuracy: 0.3158
# Epoch 41/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.7911 - val_accuracy: 0.3158
# Epoch 42/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.7493 - val_accuracy: 0.3158
# Epoch 43/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.6698 - val_accuracy: 0.3684
# Epoch 44/50
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.5799 - val_accuracy: 0.3684
# Epoch 45/50
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.5125 - val_accuracy: 0.3684
# Epoch 46/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.4651 - val_accuracy: 0.4211
# Epoch 47/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.4557 - val_accuracy: 0.4211
# Epoch 48/50
# 2/2 [==============================] - 0s 38ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.4638 - val_accuracy: 0.4211
# Epoch 49/50
# 2/2 [==============================] - 0s 33ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.4800 - val_accuracy: 0.4211
# Epoch 50/50
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.5014 - val_accuracy: 0.4211
# Sample: 1
# Probability: [[0.86805445]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: 70326.wav
# Sample: 2
# Probability: [[0.17688923]]
# Predicted: BIRD?, Expected: BIRD!, File: 51b06cca-a5aa-40fd-9091.wav
# 1/1 - 0s - loss: 0.9130 - accuracy: 0.5217
#
# Test accuracy: 0.52173912525177
# Ideal threshold is:  7    0.708496
# Name: thresholds, dtype: float32
# Area under curve, AUC =  0.5166666666666666
