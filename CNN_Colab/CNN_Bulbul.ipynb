# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = '/content/drive/My Drive/MSc_Project_Colab/mixed_114_32mels_filenames.json'


def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["log mel spectrogram"])
    y = np.array(data["labels"])
    z = np.array(data["filenames"])
    return X, y, z


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train acc")
    axs[0].plot(history.history["val_accuracy"], label="val acc")
    axs[0].set_ylabel("Accuracy")
    axs[1].set_xlabel("Epoch")
    axs[0].legend(loc="lower right")
    # axs[0].set_title("Accuracy")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train loss")
    axs[1].plot(history.history["val_loss"], label="val loss")
    axs[1].set_ylabel("Loss")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    # axs[1].set_title("Loss")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y, z = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test, z_train, z_test = train_test_split(X, y, z, test_size=test_size, random_state=0)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size, random_state=0)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test, z_train, z_test


def build_model(input_shape):
    """Generates CNN model

    :param input_shape (tuple): Shape of input set
    :return model: CNN model
    """

    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(16, (3, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 4th conv layer
    model.add(keras.layers.Conv2D(16, (1, 3), input_shape=input_shape))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    model.add(keras.layers.MaxPool2D((1, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed to dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(256))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    # model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Dense(32))
    model.add(keras.layers.LeakyReLU(alpha=0.3))
    # model.add(keras.layers.Dropout(0.4))


    # output layer
    model.add(keras.layers.Dense(1, activation='sigmoid'))

    return model


def predict(model, X, y, z):
    """Predict a single sample using the trained model

    :param model: Trained classifier
    :param X: Input data
    :param y (int): Target
    """

    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    

    # perform prediction
    prediction = model.predict(X)

    print("Probability: {}".format(model.predict(X)))

    thresh = 0.5

    if  y == 0:
        dataLabel = "BIRD!"
    else:
        dataLabel = "NO BIRD!"

    if model.predict(X)<= thresh:
        myPrediction = "BIRD?"
    else:
        myPrediction = "NO BIRD?"

    print("Predicted: {}, Expected: {}, File: {}".format(myPrediction, dataLabel, z))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test, z_train, z_test = prepare_datasets(0.2, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimiser,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=64, epochs=50)

    # plot accuracy/error for training and validation
    plot_history(history)

    #############################

    index = 0
    # make prediction on a sample
    while index < len(X_test):
        X = X_test[index]
        y = y_test[index]
        z = z_test[index]
        print("Sample: {}".format(index+1))
        predict(model, X, y, z)
        index += 1

    ###############################

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # confusion matrix
    my_threshold = 0.5

    y_pred = (model.predict(X_test)>= my_threshold).astype(int)
    cm = confusion_matrix(y_test, y_pred)
    print(cm)

    # ROC
    # print("X_test pre ravel: {}".format(X_test.shape))
    y_preds = model.predict(X_test).ravel()
    # print("X_test post ravel: {}".format(X_test.shape))

    fpr, tpr, thresholds = roc_curve(y_test, y_preds)
    # print("fpr: {}, tpr: {}".format(fpr, tpr))
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'y--')
    plt.plot(fpr, tpr, marker='.')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.show

    #One way to find the best threshold once we calculate the true positive 
    # and false positive rates is ...
    # The optimal cut off point would be where “true positive rate” is high 
    # and the “false positive rate” is low. 
    # Based on this logic let us find the threshold where tpr-(1-fpr) is zero (or close to 0)
    
    import pandas as pd
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'tf' : pd.Series(tpr-(1-fpr), index=i), 'thresholds' : pd.Series(thresholds, index=i)})
    ideal_roc_thresh = roc.iloc[(roc.tf-0).abs().argsort()[:1]]  #Locate the point where the value is close to 0
    print("Ideal threshold is: ", ideal_roc_thresh['thresholds']) 

    #Now use this threshold value in the confusion matrix to visualize the balance
    #between tp, fp, fp, and fn

    # AUC
    from sklearn.metrics import auc
    auc_value = auc(fpr, tpr)
    print("Area under curve, AUC = ", auc_value)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_40 (Conv2D)           (None, 429, 30, 16)       160
# _________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)   (None, 429, 30, 16)       0
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 215, 15, 16)       0
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 215, 15, 16)       64
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 213, 13, 16)       2320
# _________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)   (None, 213, 13, 16)       0
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 107, 7, 16)        0
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 107, 7, 16)        64
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 107, 5, 16)        784
# _________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)   (None, 107, 5, 16)        0
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 54, 3, 16)         0
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 54, 3, 16)         64
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 54, 1, 16)         784
# _________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)   (None, 54, 1, 16)         0
# _________________________________________________________________
# max_pooling2d_43 (MaxPooling (None, 27, 1, 16)         0
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 27, 1, 16)         64
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 432)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 256)               110848
# _________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 32)                8224
# _________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)   (None, 32)                0
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 123,409
# Trainable params: 123,281
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/50
# 2/2 [==============================] - 1s 214ms/step - loss: 0.8192 - accuracy: 0.5000 - val_loss: 2.3089 - val_accuracy: 0.4211
# Epoch 2/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5572 - accuracy: 0.6806 - val_loss: 2.2513 - val_accuracy: 0.4211
# Epoch 3/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4702 - accuracy: 0.7778 - val_loss: 1.9443 - val_accuracy: 0.4211
# Epoch 4/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3922 - accuracy: 0.8611 - val_loss: 1.3946 - val_accuracy: 0.4211
# Epoch 5/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3216 - accuracy: 0.9167 - val_loss: 1.4064 - val_accuracy: 0.4211
# Epoch 6/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2724 - accuracy: 0.9167 - val_loss: 1.5675 - val_accuracy: 0.4211
# Epoch 7/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2475 - accuracy: 0.9167 - val_loss: 1.4840 - val_accuracy: 0.4211
# Epoch 8/50
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2228 - accuracy: 0.9306 - val_loss: 1.1900 - val_accuracy: 0.4211
# Epoch 9/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1656 - accuracy: 0.9583 - val_loss: 0.9443 - val_accuracy: 0.4737
# Epoch 10/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1412 - accuracy: 0.9722 - val_loss: 0.8398 - val_accuracy: 0.5263
# Epoch 11/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1519 - accuracy: 0.9583 - val_loss: 0.8510 - val_accuracy: 0.5263
# Epoch 12/50
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1253 - accuracy: 0.9722 - val_loss: 0.9126 - val_accuracy: 0.4737
# Epoch 13/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1161 - accuracy: 0.9583 - val_loss: 0.9768 - val_accuracy: 0.4211
# Epoch 14/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1274 - accuracy: 0.9583 - val_loss: 1.0157 - val_accuracy: 0.4211
# Epoch 15/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0793 - accuracy: 0.9861 - val_loss: 1.0452 - val_accuracy: 0.4737
# Epoch 16/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0588 - accuracy: 1.0000 - val_loss: 1.0136 - val_accuracy: 0.4737
# Epoch 17/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0747 - accuracy: 0.9861 - val_loss: 0.9596 - val_accuracy: 0.5263
# Epoch 18/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0976 - accuracy: 0.9722 - val_loss: 0.9208 - val_accuracy: 0.4737
# Epoch 19/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0868 - accuracy: 0.9722 - val_loss: 0.9123 - val_accuracy: 0.4737
# Epoch 20/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1022 - accuracy: 0.9861 - val_loss: 0.9833 - val_accuracy: 0.4737
# Epoch 21/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0569 - accuracy: 0.9861 - val_loss: 1.1220 - val_accuracy: 0.4211
# Epoch 22/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0664 - accuracy: 0.9722 - val_loss: 1.2525 - val_accuracy: 0.4211
# Epoch 23/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1193 - accuracy: 0.9722 - val_loss: 1.2139 - val_accuracy: 0.4211
# Epoch 24/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0481 - accuracy: 0.9861 - val_loss: 1.0072 - val_accuracy: 0.4737
# Epoch 25/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0301 - accuracy: 1.0000 - val_loss: 0.8425 - val_accuracy: 0.5263
# Epoch 26/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.7420 - val_accuracy: 0.5263
# Epoch 27/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0540 - accuracy: 1.0000 - val_loss: 0.6960 - val_accuracy: 0.5263
# Epoch 28/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0490 - accuracy: 1.0000 - val_loss: 0.6917 - val_accuracy: 0.6316
# Epoch 29/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0459 - accuracy: 1.0000 - val_loss: 0.7071 - val_accuracy: 0.6316
# Epoch 30/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 0.7341 - val_accuracy: 0.6316
# Epoch 31/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.7695 - val_accuracy: 0.5789
# Epoch 32/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.8099 - val_accuracy: 0.5789
# Epoch 33/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.8460 - val_accuracy: 0.5789
# Epoch 34/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.8793 - val_accuracy: 0.5263
# Epoch 35/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.9068 - val_accuracy: 0.5263
# Epoch 36/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.9092 - val_accuracy: 0.5263
# Epoch 37/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.8873 - val_accuracy: 0.5263
# Epoch 38/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.8702 - val_accuracy: 0.5263
# Epoch 39/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.8595 - val_accuracy: 0.5789
# Epoch 40/50
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.8510 - val_accuracy: 0.5789
# Epoch 41/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.8515 - val_accuracy: 0.4737
# Epoch 42/50
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.8587 - val_accuracy: 0.3684
# Epoch 43/50
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.8788 - val_accuracy: 0.3684
# Epoch 44/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.9123 - val_accuracy: 0.3158
# Epoch 45/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.9479 - val_accuracy: 0.3158
# Epoch 46/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.9724 - val_accuracy: 0.3158
# Epoch 47/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0203 - accuracy: 0.9861 - val_loss: 0.9451 - val_accuracy: 0.3158
# Epoch 48/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.8895 - val_accuracy: 0.3684
# Epoch 49/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.8580 - val_accuracy: 0.3684
# Epoch 50/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.8493 - val_accuracy: 0.4737
# Sample: 1
# Probability: [[0.35073945]]
# Predicted: BIRD?, Expected: BIRD!, File: 191743.wav
# Sample: 2
# Probability: [[0.8868197]]
# Predicted: NO BIRD?, Expected: BIRD!, File: 00cb94c4-f8c0-444c-ad2f-2c22cd904835.wav
# Sample: 3
# Probability: [[0.80763215]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: 70323.wav
# Sample: 4
# Probability: [[0.4317344]]
# Predicted: BIRD?, Expected: BIRD!, File: 00c113b9-7156-4b34-8d50.wav
# Sample: 5
# Probability: [[0.62689364]]
# Predicted: NO BIRD?, Expected: BIRD!, File: 1052.wav
# Sample: 6
# Probability: [[0.9805832]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: 0a4e8000-574c-46b8-a847.wav
# Sample: 7
# Probability: [[0.42890868]]
# Predicted: BIRD?, Expected: NO BIRD!, File: f9169ea6-2656-426a-8760.wav
# Sample: 8
# Probability: [[0.946092]]
# Predicted: NO BIRD?, Expected: BIRD!, File: 1050.wav
# Sample: 9
# Probability: [[0.9408295]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: 70327.wav
# Sample: 10
# Probability: [[0.85646737]]
# Predicted: NO BIRD?, Expected: BIRD!, File: 00a992ec-9032-4707-a96d-9d40e9ea95a2.wav
# Sample: 11
# Probability: [[0.17294492]]
# Predicted: BIRD?, Expected: BIRD!, File: 7c097bed-d9d1-4e13-a4e0-e460d9122e75.wav
# Sample: 12
# Probability: [[0.46813706]]
# Predicted: BIRD?, Expected: NO BIRD!, File: 70322.wav
# Sample: 13
# Probability: [[0.54389066]]
# Predicted: NO BIRD?, Expected: BIRD!, File: 7c48e597-b431-4270-a857-3ea73222b670.wav
# Sample: 14
# Probability: [[0.45028326]]
# Predicted: BIRD?, Expected: NO BIRD!, File: 00ee6deb-2307-4abc-a6a5.wav
# Sample: 15
# Probability: [[0.34366855]]
# Predicted: BIRD?, Expected: NO BIRD!, File: 87.wav
# Sample: 16
# Probability: [[0.6666314]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: 70326.wav
# Sample: 17
# Probability: [[0.57002085]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: 00a76d1a-d12b-411e-a4ca-61720d79aaba.wav
# Sample: 18
# Probability: [[0.38313425]]
# Predicted: BIRD?, Expected: NO BIRD!, File: 00ca0484-3d4d-4e0d-a5c5-b0386f1f506c.wav
# Sample: 19
# Probability: [[0.6730007]]
# Predicted: NO BIRD?, Expected: BIRD!, File: 00e10c18-3dae-4303-bfe2.wav
# Sample: 20
# Probability: [[0.43729758]]
# Predicted: BIRD?, Expected: BIRD!, File: 00dbd628-2bc0-4881-b573.wav
# Sample: 21
# Probability: [[0.8777069]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: 00cff0c3-7b4f-4d2a-afa1-3639e7245596.wav
# Sample: 22
# Probability: [[0.80068785]]
# Predicted: NO BIRD?, Expected: NO BIRD!, File: 99.wav
# Sample: 23
# Probability: [[0.26452717]]
# Predicted: BIRD?, Expected: BIRD!, File: 1055.wav
# 1/1 - 0s - loss: 0.7845 - accuracy: 0.5217
#
# Test accuracy: 0.52173912525177
# [[5 6]
#  [5 7]]
# Ideal threshold is:  11    0.570021
# Name: thresholds, dtype: float32
# Area under curve, AUC =  0.5833333333333334
