# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,'/content/drive/My Drive/MSc_Project_Colab/BAD_PyTorch/')

# %%
# !pip install torchaudio
# Out:
# Collecting torchaudio
#   Downloading torchaudio-0.9.0-cp37-cp37m-manylinux1_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 8.0 MB/s
# Requirement already satisfied: torch==1.9.0 in /usr/local/lib/python3.7/dist-packages (from torchaudio) (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.9.0->torchaudio) (3.7.4.3)
# Installing collected packages: torchaudio
# Successfully installed torchaudio-0.9.0

# %% [markdown]
# **CNN**

# %%
from torch import nn
from torchsummary import summary


class CNNNetwork(nn.Module):

    def __init__(self):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(
                in_channels=1,
                out_channels=16,
                kernel_size=3,
                stride=1,
                padding='valid'
            ),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.001),
            nn.MaxPool2d(kernel_size=3)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(
                in_channels=16,
                out_channels=16,
                kernel_size=3,
                stride=1,
                padding='valid'
            ),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.001),
            nn.MaxPool2d(kernel_size=3)
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(
                in_channels=16,
                out_channels=16,
                kernel_size=3,
                stride=1,
                padding='valid'
            ),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.001),
            nn.MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=0)
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(
                in_channels=16,
                out_channels=16,
                kernel_size=3,
                stride=1,
                padding='valid'
            ),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.001),
            nn.MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=0)
        )
        self.flatten = nn.Flatten()
        self.dropout = nn.Dropout(p=0.5)
        self.linearA = nn.Linear(448, 256)
        self.batchnormA = nn.BatchNorm1d(256)
        self.leakyrelu = nn.LeakyReLU(0.001)
        self.linearB = nn.Linear(256, 32)
        self.batchnormB = nn.BatchNorm1d(32)

        self.linear = nn.Linear(32, 1)
        # self.sigmoid = nn.Sigmoid()

    def forward(self, input_data):
        x = self.conv1(input_data)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.flatten(x)
        x = self.dropout(x)
        x = self.linearA(x)
        x = self.batchnormA(x)
        x = self.leakyrelu(x)
        x = self.dropout(x)
        x = self.linearB(x)
        x = self.batchnormB(x)
        x = self.leakyrelu(x)
        x = self.dropout(x)
        logits = self.linear(x)

        # predictions = self.sigmoid(logits)
        return logits


if __name__ == "__main__":
    cnn = CNNNetwork()
    summary(cnn.cuda(), (1, 80, 698))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 16, 78, 696]             160
#        BatchNorm2d-2          [-1, 16, 78, 696]              32
#          LeakyReLU-3          [-1, 16, 78, 696]               0
#          MaxPool2d-4          [-1, 16, 26, 232]               0
#             Conv2d-5          [-1, 16, 24, 230]           2,320
#        BatchNorm2d-6          [-1, 16, 24, 230]              32
#          LeakyReLU-7          [-1, 16, 24, 230]               0
#          MaxPool2d-8            [-1, 16, 8, 76]               0
#             Conv2d-9            [-1, 16, 6, 74]           2,320
#       BatchNorm2d-10            [-1, 16, 6, 74]              32
#         LeakyReLU-11            [-1, 16, 6, 74]               0
#         MaxPool2d-12            [-1, 16, 6, 24]               0
#            Conv2d-13            [-1, 16, 4, 22]           2,320
#       BatchNorm2d-14            [-1, 16, 4, 22]              32
#         LeakyReLU-15            [-1, 16, 4, 22]               0
#         MaxPool2d-16             [-1, 16, 4, 7]               0
#           Flatten-17                  [-1, 448]               0
#           Dropout-18                  [-1, 448]               0
#            Linear-19                  [-1, 256]         114,944
#       BatchNorm1d-20                  [-1, 256]             512
#         LeakyReLU-21                  [-1, 256]               0
#           Dropout-22                  [-1, 256]               0
#            Linear-23                   [-1, 32]           8,224
#       BatchNorm1d-24                   [-1, 32]              64
#         LeakyReLU-25                   [-1, 32]               0
#           Dropout-26                   [-1, 32]               0
#            Linear-27                    [-1, 1]              33
# ================================================================
# Total params: 131,025
# Trainable params: 131,025
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.21
# Forward/backward pass size (MB): 22.94
# Params size (MB): 0.50
# Estimated Total Size (MB): 23.66
# ----------------------------------------------------------------

# %% [markdown]
# Train the model

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
import torchaudio

from random import seed
from random import random
import matplotlib
import matplotlib.pyplot as plt

from dcasedataset import DCASE_Dataset

ANNOTATIONS_FILE = '/content/drive/My Drive/DCASE_Datasets/labels/bvwarblr_25percent.csv'
AUDIO_DIR = '/content/drive/My Drive/DCASE_Datasets/audio/'
SAMPLE_RATE = 22050
DURATION = 10
NUM_SAMPLES = 22050 * DURATION


BATCH_SIZE = 16
EPOCHS = 30
LEARNING_RATE = 0.001

def create_data_loader(train_data, batch_size):
    train_dataloader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
    return train_dataloader


def train_single_epoch(model, data_loader, loss_fn, optimiser, device):
    size = len(data_loader.dataset)
    stages_per_epoch = len(data_loader)
    average_loss = 0
    print("Dataset size: {}".format(size))
    print("Stages per epoch {}".format(stages_per_epoch))
    
    for input, target in data_loader:
        input, target = input.to(device), target.to(device)
        # print(input.shape)
        # print(target.shape)

        # for index, signal in enumerate(input):
        #   # seed(1)
        #   value = random()

        #   if value > 0.75:
        #     signal = t1masking(signal)
        #     signal = t2masking(signal)
        #     signal = fmasking(signal)
        #     input[index] = signal


        # def plot_spectrogram(spec, title=None, ylabel='freq_bin', aspect='auto', xmax=None):
        #   fig, axs = plt.subplots(1, 1)
        #   axs.set_title(title or 'Spectrogram')
        #   axs.set_ylabel(ylabel)
        #   axs.set_xlabel('frame')
        #   spec = spec.cpu()
        #   spec = spec[0,:,:]
        #   im = axs.imshow(spec, origin='lower', aspect=aspect)
        #   if xmax:
        #     axs.set_xlim((0, xmax))
        #   fig.colorbar(im, ax=axs)
        #   plt.show(block=False)

        # for signal_mod in input:
        #   plot_spectrogram(signal_mod)

        # calculate loss
        prediction = model(input)
        sigmoid = nn.Sigmoid()
        target = target.unsqueeze_(1)
        target = target.type(torch.cuda.FloatTensor)
        loss = loss_fn(sigmoid(prediction), target)
        print(f"loss: {loss.item()}")
        average_loss += loss.item()

        # backpropagate error and update weights
        optimiser.zero_grad()
        loss.backward()
        optimiser.step()

    print(f"Average loss: {average_loss / stages_per_epoch}")


def train(model, data_loader, loss_fn, optimiser, device, epochs):
    for i in range(epochs):
        print(f"Epoch {i+1}")
        train_single_epoch(model, data_loader, loss_fn, optimiser, device)
        print("---------------------------")
    print("Finished training")


if __name__ == "__main__":

    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
    print(f"Using {device}")

    # instantiate dataset object and create data loader
    mel_spectrogram = torchaudio.transforms.MelSpectrogram(
        sample_rate=SAMPLE_RATE,
        n_fft=1024,
        hop_length=316,
        n_mels=80,
        power=0.33
    )

    t1masking = torchaudio.transforms.TimeMasking(time_mask_param=40)
    t2masking = torchaudio.transforms.TimeMasking(time_mask_param=40)
    fmasking = torchaudio.transforms.FrequencyMasking(freq_mask_param=10)

    dcase = DCASE_Dataset(ANNOTATIONS_FILE,
                            AUDIO_DIR,
                            mel_spectrogram,
                            SAMPLE_RATE,
                            NUM_SAMPLES,
                            device)
    
    train_dataloader = create_data_loader(dcase, BATCH_SIZE)

    cnn = CNNNetwork().to(device)
    print(cnn)

    # initialise loss funtion + optimiser
    loss_fn = nn.BCELoss()
    optimiser = torch.optim.Adam(cnn.parameters(), 
                                 lr=LEARNING_RATE)

    # train model
    train(cnn, train_dataloader, loss_fn, optimiser, device, EPOCHS)

    # save model
    torch.save(cnn.state_dict(), "/content/drive/My Drive/MSc_Project_Colab/BAD_PyTorch/cnn.pth")
    print("Trained cnn saved at cnn.pth")
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/598e5ec5-c51d-4894-a78e-839942b8eca6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4df86a61-40ac-4b34-a9b4-4305c9393c00.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/adc6f109-13a8-4865-a80f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/3177ebd9-a62a-42b9-a818.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c8b19270-ee25-493c-b356.wav
# loss: 0.11421280354261398
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/733bf910-a245-4240-a5ee-00096bbbb1dc.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5534a0e5-7497-4354-a335-876aac013489.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6a2cbb2d-77bb-4e7c-a4df-43b85f93b4f3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4ac10d10-7639-4c4f-a8e7-7eb994909ce6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/440c3c4d-c365-49b0-a2d5-9f915ebcf962.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/53ef2ad1-b5c1-403a-a996-1b7a24bd6f45.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7afab54c-7e6b-4f3a-a3d1-417dc1f8f6bc.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5441e449-0e44-4a81-a14a-e256ff3df11c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7af073e5-f183-4798-a23b-f45a8cc15867.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/76693192-cba9-4e20-ad1c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/67936ed2-c5bf-42bc-a68a-caa999f9ef8b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5f85d106-8cb2-4d7a-aa1b-40ba7fb39189.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/62e24e9f-5f18-4a0b-a077-7f0b24534c4a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/634c1f03-2c6a-434d-be35.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/41ba5961-2171-4436-abea-a11f037dddb2.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7d2bde63-348a-4f88-a583-5f7d91b0a650.wav
# loss: 0.07941540330648422
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6fcdc163-6419-4b98-a141-fd75ddaf166b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/74840389-1bb3-40c8-8b1c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5cbe46cc-07db-46f6-a851-725ef4046d31.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/747a9320-7454-4bfa-a756-3850564b6854.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/963d9691-1e65-40ed-84c6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6b13441e-0606-43c5-a63a-5a27db9b24dd.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/617a2849-53bd-46d2-ac81-fe4b1c1bad97.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/477910f8-f805-4f68-a084-4101828b6c42.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5007eff9-e8c5-43da-a2f7-d2ba48b5bea6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5ae10ae8-4d3f-4151-aa43-a5bd08c2b323.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/5997cfa5-0316-4628-8f40.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/43550cb6-6db6-452c-aaa9-ac7bedecffd8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/2066b2d3-4e10-40be-ae00.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/401ad998-4b85-4949-a349-9247da74201e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/56887421-dde0-496a-a4ae-b4b66b20761c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7286e497-edf8-405b-a666-8a695bfd908c.wav
# loss: 0.26135724782943726
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4eaa2e9c-6760-4bcf-a5b9-b2f9ee08ee70.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/518f9d6b-ab8a-48d7-a78b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/41e94c2a-09b9-4568-abab-3aa5c6b9d113.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/51c93921-470a-4d84-84ff.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/4342217a-7c20-4139-a9cb.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/7b48cc7b-d6ef-4d13-a44e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/fca8dce2-6a0f-4698-9d9f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/562b260f-decc-4609-a0c8-0fce3a8b24a9.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/8f34b0a2-40f3-42c3-8f92.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/72a3f886-6f59-4106-a831-5ae7f5a03064.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/fb0c7bb8-ccd4-40ca-92c0.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5c5684f4-8c85-4ead-a80b-606d5a468830.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7c589605-a395-4fda-a0cb-872fa98da420.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/61877e27-7c3f-4eaa-a095-49cc9a3b071d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/44af3e40-83c6-41a6-b69e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/163638ef-6b4f-4f86-b543.wav
# loss: 0.31816163659095764
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/63cdc04e-1833-49f7-a899-2779dd46ad4f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7823aa85-3c96-4c20-a1f5-98c99197d877.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4e3dc9f8-220c-4704-a0be-78d86a2f2e55.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/792232a4-7b5d-4e7d-a02b-36d2f9a8b01d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7d4fc614-4391-4566-ac2d-e129ee7549b0.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/5854a3ef-d2c7-4c03-932b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/612bb69e-2277-46f8-a707.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4d93885c-acaa-4b08-ab4e-09be753bffd8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/542f9549-6686-4558-a6ea-dc64169e7260.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/cec8fc1f-2f8f-41db-80ed.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5d2cc499-308b-46a4-ae67-c59c34b6e08b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/aad062c8-59af-48a5-9021.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/676c473a-5a04-4519-9ac8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/50d0c9e8-fd4e-47f3-aecb-048448f187bb.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/b1bcb928-cc1b-45bc-bcdd.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/06f0ab7d-f6c3-4ed8-be35.wav
# loss: 0.2868117094039917
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5686cafd-03a3-40e9-a995-11c59f1276cc.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/4e5fff44-7e94-4705-832e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/026eceb5-3e21-4fdc-b6d3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5e70ff4e-bd94-4bb9-a2b1-df9a794647bd.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/d3e9c456-8b9d-4caf-8cc9.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6d73f8e1-48cd-4f1f-a7e3-3ca8a2f877fe.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/417765f5-d384-4e30-af19-1d79ba101c91.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4244acdf-139b-4a77-affc-8febc5656260.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4445e6fb-adb3-4c9e-a9e2-30601955204b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6af55c2e-e7c2-4f7a-ab81-b7d763f72485.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4876b643-edff-4f5a-a626-132f7aace431.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7eb95c12-6c66-4b5c-afa0-17407778e9dd.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/90012edc-e26e-4019-b4b1.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5b6bfb7f-c50d-4325-a382-9a027fda81c0.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6c298543-e50e-4b41-a2af-7aeeb00fb3e7.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/58afeb64-1178-41f1-a64f-e79503d101d6.wav
# loss: 0.23914065957069397
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4505438e-ff9d-4957-ac4b-adf62b3b7b83.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6f5e3347-56ee-40d6-aa84-cc3bdd201eff.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/654aad19-bf19-48a4-a231-b572e28bc221.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/274cd283-e783-4c81-8861.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/40b0b8c8-9309-46da-af23-21ff611ef23c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/e4e973e4-b48c-4dc7-accc.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/695b5cb5-def4-40e3-a6fe-d7234e7aa1c0.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/607e98b8-201a-441c-a376-aa0f02662617.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/21033bdb-251f-4ccc-ad10.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/79a9f596-11b4-4210-a9f7-8409e9fd63ed.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/764c3e00-eae5-42fe-ace2-7f65bdd2c3a3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/58cbf8da-a761-44ee-aa27.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/0b2dda10-f2b5-4cce-be76.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6c695d41-2fd0-4fb5-a2f7-c10fbbfed714.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/73db693b-f6e0-428d-a03c-d1fa02b8db78.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/3fc84c55-a0b4-44ff-a84f-1cc7b11faf13.wav
# loss: 0.42028364539146423
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5cac1600-e445-48aa-a77b-828663ef1d0b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6c662e8d-f0b9-443c-ade6-109884b94ce3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5da9c517-529c-4f43-a4a7-ce64b68089d1.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/576c3847-a601-4b19-a622-5742860161c6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/66d7a327-a8f5-4b22-acf6-39a6e6d39d86.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/592c5f8e-8312-487b-a81f-c9cb6aa9eb37.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/60984998-8a0a-4a27-adf5-22c21d452e22.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/a74782af-439e-4d87-987a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/79871c60-680f-481e-a8c5-d98abde8f802.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/78de28ea-60f4-4c29-a285-2087441e8415.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6ffac986-263b-4e7e-af68-fcbdf3357e70.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/aa2834ad-f391-4b98-b3db.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4b53bb8a-bc25-4d5e-a2a7-2cbac740f296.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5fc76262-4c02-4c56-a3e0-bbfdef532eb7.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/48b2fd5b-c083-486e-a2d6-f6674e6b5e5a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6b8766d7-52bc-4b73-a639-aa824129944c.wav
# loss: 0.13253118097782135
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7a5b2b74-7cef-4204-a353-a94f3bb1d355.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/7f8e0cf7-78ff-4896-a5d2.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/dcd146b4-0921-4e81-8443.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/57278de7-4c50-4e05-add4-dc858dd448c4.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5e1ced8b-4f75-4a47-a1e6-2e3ffc41701d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/548ebdb2-c257-4c59-ad57-b0a797115cf1.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/330e695e-70de-40de-ad12.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/74e55f16-a9bf-4e5e-a18e-46f749143c3e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/54b18385-9f97-4fd1-abe1-cd798d115265.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/650db552-91fd-4f53-adfd-52855ba7323a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/6b213469-c1e8-422d-91b0.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7684f9d2-dede-4d20-a44f-fa09f6e4240e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4c9de8ac-be04-4203-a69a-7f56c3390e01.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/63888c71-0473-4f80-a6b6-26fc6ad2088c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5cd93189-06f4-463f-aed0-cacb9f988b59.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/735d68ab-ed57-48ef-a003-b3fe02087c94.wav
# loss: 0.268385648727417
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6e318511-c40b-4f7a-abc0-16b9c465a189.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/7494305e-413f-475a-a0c2.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/57f25f19-0feb-416c-a227-f047d694bd72.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/95498045-aee7-4049-8c6a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/47509a76-7a6b-4e50-aa17-6d6a4e62de2a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/3fff5fd3-2f23-46ed-ac2f-174e25acc918.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/6cce555c-4f77-436d-aada.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/46b16139-2347-4b19-a211-f8ae8edf05fb.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/19ba0c54-2972-4ceb-88d2.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/7dba2047-bfa9-4bf3-abca.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5c28d854-a517-467f-a8db-0fe713b4f981.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6bdf686c-8c0c-4a52-af74-731a14b72607.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/5a0b29b0-af92-4b44-846a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/6ff47467-4bc2-477a-b811.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4e8404b1-859d-4bf9-aea9-f08bda50ff1c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/d9434bf2-6827-4b58-9791.wav
# loss: 0.23105478286743164
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/2838a50d-ccd7-4f88-a1c6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4516737c-0690-4da9-a161-2ffe27fa8506.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/68f4eaa1-bec1-420f-a707-78964d2295c8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7714b9dc-8af8-4e8c-ace4-d4abcf9ffe72.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/766f4677-5e0f-4870-ae16-9b9369040555.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5df107e7-20b3-4338-a227-0e9d1129d4a3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/31f95342-5297-4184-95b1.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/184b0704-bb06-4172-bd6d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/0211308a-d8d7-4012-bb72.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/47c227a6-997d-4197-ae70-561dd94ed2c7.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/ad9ee878-79e4-4786-97b6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/724d5817-600d-4193-afcf-c67509c0134f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/40676aa6-f07d-4231-b84f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/535eb5eb-fee9-40c3-a394-c76198403fe0.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/bf07d954-a56d-4897-a35d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/746b5e54-9203-48e7-adfc-8404088e3234.wav
# loss: 0.305761456489563
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7a7df796-d716-45f2-a145-5b203d0b7fc0.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/fdf87f52-a876-4903-92e6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/51dcc956-08a9-4c5d-afe7-705b463fe1bb.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/4730e046-dca4-4f41-b890.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/61ec0e36-c559-4553-adde-372561e51d88.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/98633133-ee52-4a83-a125.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/420a63b7-67d9-46c8-b903.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/ea4f8763-04b8-49d6-99b6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/9ce38206-d844-46dd-a742.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4da7956e-23fe-47dc-a4de-87409eb86d6a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/bb30467e-308c-490b-b2a8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7ca4852b-5ed3-40f1-ab87-6dc04ff3e966.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/604d9be6-aadc-481c-ae48-7b1f4ebfaf0e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/4870a14f-b99b-4146-88ae.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/62b12a8c-8585-4a7b-aa55-d6b08986c79b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/71174232-27b9-4dae-a913-dc58eb9b9c2f.wav
# loss: 0.5631518959999084
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/58cc0ea1-76f0-44f3-a922-f87f193777c6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/425f8668-35cf-48b6-aa98-341961d5772a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c6d5904c-b378-4175-8a85.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/619f5b7f-790b-46a9-a03a-10663b4f175a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/608a44cf-b591-4516-a9bf-1ca0b6ebb551.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/227c09dd-4ddc-4b22-ba18.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/52c19de7-e446-48b5-a59a-70efdd1cfb4f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5138b1cd-d4b0-4b1f-a36a-7f6143937350.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5675fcd8-e211-4732-a024-5c2624ee7028.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/63812fde-c75a-4289-9252.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5d4a8a31-a282-43fc-a040-03c00c1e8f28.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4e91bca4-9877-4169-a355-b216e0422fee.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c4e9f72e-f01a-456c-98a7.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7f7e8532-549a-4054-a018-b3378b22e883.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6a28d0f1-343f-42f0-a5f1-ae6ae2589d0e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7a82ff97-02bd-49c5-a011-0ee0aade0f66.wav
# loss: 0.1536829024553299
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/447de598-1b05-42d6-af3e-b6d4b434878b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/43d586ba-d3ec-43c1-a0ef-50a52bffb02b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/634ddfab-745d-4c3b-a8de-312299894197.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/47240129-5048-4b13-ad12.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/654eb453-319f-4061-aff5-06b523f280b6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4515c374-c61f-4dd8-a7ac-02acc22688e5.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6b0b9126-4fac-44ec-abe6-b6a688302c20.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/b1fa3e52-c709-447a-b530.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/114142f2-e22d-4e02-95d0.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7030db5a-5e5d-4dac-a2c1-7bf9922a2c76.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7bde2751-1fa6-40b2-a900-66ce94f46d0f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/a59a5fb6-231f-4787-827d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7d9e10f9-ecbe-4783-a533-fc7fc201fd9d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/dafeac88-20ae-4701-a369.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/69c4bc35-b87a-42bc-a789-9b66f45e8bde.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/31a68abc-3956-4dfd-a59c.wav
# loss: 0.3431621193885803
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/56adb26d-a4dd-435e-a525-d464d5882b88.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4cd4a486-c14f-4725-a7f6-b4ca9715dd7e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7fddecfe-aabb-4241-a2db-c4b3d0b4fa83.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/70304363-e9e5-4c18-af7c-7255a7c42ab4.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5f3976bb-3b25-45b2-af13-8a3661c31f6a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/34276ce6-004b-4118-9cf0.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5daa0e27-e605-4ac0-ab32-074e870bbb3d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/97e88c1a-9ffb-4947-9e1e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4bfea078-b916-4019-a152-dbce6d08cd80.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/6e052246-6c50-4555-bc58.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4127fa3f-58bc-4bc1-abe4-a96732f514e9.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4dcf417b-3041-4aee-a05d-af989f8e35a1.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/731ed3d1-2780-46a2-a9c3-1acfe3973749.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6a9d4ec8-9453-43a7-a646-ee2d9c1738b8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7cf44505-1d6e-49a2-a779-439078a4ca1d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7c8b6b35-fe9a-4323-ac59-82bb5d666190.wav
# loss: 0.25824716687202454
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/47fd6307-5e81-4b4a-a9bb-96bb4c988fed.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/47f72613-e816-4092-9d07.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c63d0bd3-516d-44be-a64c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/43e64024-f6ec-4a94-aa7c-8cc915c58245.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/2710f25b-5de0-460a-b187.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/fcd2749d-e7d3-4098-9be8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4a38f934-eba9-46a4-aebf-ff53626b80e6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/62d09b56-9b83-443f-afa3-12d849d728fa.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/571719ec-9876-4927-a47b-10892305fc26.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/76033baf-b0eb-4512-a758-393f6a40e73d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4f9468e0-c2eb-42c1-a9d4-75d99838f62b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c060b496-091a-4ba9-8bb1.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/14b5f844-9586-40d3-ba07.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4d4705ec-c638-449d-aa0d-7c54eed1240a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/46e4ce95-eb84-40dc-ae4d-dd03ecfdcf6e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/be4e9e69-cb38-4a22-89ff.wav
# loss: 0.3061259984970093
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5ebd44bd-849d-4ff5-a693-c3e25eff7fb2.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6077987d-4c52-4992-ad51-b38bb2bb0e62.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7a8c77ab-41c1-4514-a59c-5d97073f7d4b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4c6e2e8c-d27a-4dda-ae24-7326e2611c91.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/439f9a23-594e-4350-ac6d-f2476d6cdae1.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/618811bb-7faf-4a91-acd3-c022667f31b4.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/66fa3b6d-820b-41eb-a59e-ef8ad0a6814a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/64afcba5-90c8-4ad5-abc6-de5bf36e164a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/42375574-ead2-4ebd-a361-1afb5a55847e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7462eba1-4ec5-4b59-ade3-490de68f3250.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/494805a8-3500-42fe-a6ca-d3b6624dcaef.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/3c7f5413-66a5-432f-9d8c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/befbd42f-c0dd-4b34-9c12.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6ce3ab6f-ede5-4dfd-a81f-8f07157efcde.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6f4b0765-d1e7-4eed-acad-d619c8fc2dac.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6a66b8ba-6068-482a-a8f5-1f262d207890.wav
# loss: 0.5428794026374817
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5abcda24-2ad4-4381-aaa9-75336d80d2d3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5a21f56a-7988-45b6-aa85-b4f2a84a09f5.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7b35ece4-05bb-441a-a701-f14e62ffc00d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/9d41b1d9-fed4-4a00-8354.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/6cabbe11-cb40-4d29-b621.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/72cb08fe-2459-43a8-9dc4.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7a7d2379-4656-4c41-ac45-6e820457c9a8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/3f94efbe-bc6a-4090-ab08-c29b274f057b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/69881e34-2746-4b85-a821-613a8af04556.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c6a7f246-1266-41fc-a5f2.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/519440d1-c47e-4fb7-a986-61044466830b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/394ddbe6-8ff1-4744-a547.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6a6c152c-ef04-4dc7-a907-516d7246cc72.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/d31f3d2c-b3fc-47d3-94c9.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6be0d544-860e-4584-a3b0-433a368dcf20.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/43f50e58-d2c0-4ccf-aa36-974d8aa63eda.wav
# loss: 0.3509208858013153
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7bb8554d-c830-4554-a2b4-184d7f02a821.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/55420aee-89ac-4b0b-ac1b-73925cf8b3f1.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/4827d25e-e974-47cd-bf15.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/50e4ec4d-16bb-4fb4-a1eb-9041ad8ea8b4.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7d582c01-064d-43cc-a694-c5496db68719.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/2fb9eda4-b5ac-49b3-a37a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/a7b6ebc5-1c75-451a-8598.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/00d14a65-1ccd-48e1-8dbf.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5f96ab16-0443-4df5-ab59-211af23dc0fd.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5feafb9a-ae68-4e4f-a89d-4ffe5d00ad15.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/645e7c76-5715-4725-ab1d-8a8563b9b377.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7a39e73e-a341-46c5-a161-2324b5a5d46e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4e07561d-f7bc-4cb4-adc7-a91d45005936.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/78f5aebc-bec7-4219-a0e9-55319cc3c25f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/53ba9096-531c-4f0e-ab2f-1f697466281d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/359dc9a4-0ec4-4991-add2.wav
# loss: 0.11824880540370941
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6dc30a0c-fe3e-4811-aab5-07c70e0a29cc.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/735056ea-1a81-48ce-aa7e-1e0254524f08.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5e806060-da81-433d-ada4-eca3a1cb60fb.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/47f1dd6d-17fa-4ae6-adf2-81392723780e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5b6d2248-84cb-493f-a4eb-b5a5888ff679.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4b35a524-91d4-4955-a008-70a5f8672463.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/a5071cb9-e8b0-4fd5-93b1.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/8901a716-f4cf-4df1-8574.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7cb2fbe1-51a9-4673-a38a-75379460591c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/420a9279-422e-4a71-aa27-c488cb20344a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/42fa8484-fcdc-4127-ade0-6de8bb0d54b0.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5abd0148-06e8-45b7-a9b1-7ba6f1f95ad6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/89848f5b-c381-428d-ac18.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7de24bdb-0c66-49b8-a6f6-eca954669707.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/54fe424b-8faa-4af5-ab04-f4ffbb726476.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/64036333-5e14-4a1d-ade3-829d9bee612e.wav
# loss: 0.39482492208480835
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6e339912-3435-4c99-a2e1-2dbcd3779e23.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/55f0011b-9450-4cdc-a197-7ecd881ca2ee.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/76f91a89-a966-47f2-ae29-096a01eabcd7.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/64631c07-4e39-4535-aeee-63f69173b5d7.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5ffe0797-1d2f-41b0-a3ea-f467a69bf672.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/73f30c7a-cd9f-4b4a-a855-398a9d4dd803.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/575802ba-c572-4ee9-ad2d-38a5eeee8105.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/622993d6-eab6-4f05-9729.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/52e8e42f-7d85-4813-a8f6-f292877805d0.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/06a62f34-83ed-490b-8440.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/51ba1af2-468c-4b6f-aefe-c087c8fe2e2f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4fbc5167-5896-4133-ad99-1dfa25ddc2de.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/541f32d6-7bd0-4c48-9685.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7c5a7ff8-16e0-49a5-aa6f-55d785b7800e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/90138315-4b00-4ce3-8bd6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/55c210e4-bdbe-4879-ab8f-c83ad19c1fff.wav
# loss: 0.1621241420507431
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/468d1d2f-a86f-455d-a5d6-8e659d2f067d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c56549cc-af7b-4269-8fc5.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/7f774666-5c38-4b5e-9840.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4923b290-f13f-4e3b-a1bb-49dac3d96c25.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6e66712d-d3c2-4ed1-a2f1-26b8f85800f8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7d0d07ad-eb98-4304-a1cf-a4784ffef787.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/52c89f1f-6078-4b5a-aa6c-3f58cf7286ab.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/9f1e393b-990d-4686-9d35.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/2854f37c-28ca-4286-8a5d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/51305f6b-d25d-4b3b-a76f-e307b7442396.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/43d1592d-e43c-45b0-ae11-f00f16004e3c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c79b1382-ad04-498c-a3a6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/2cae2622-f230-426f-98b9.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/29a0fa99-5c14-4e57-9cad.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/8ef7c879-c9bf-4702-b6a2.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/59b2c21c-4099-4bd4-a099-0acda52a50b6.wav
# loss: 0.17374031245708466
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4ab397c6-1f16-49bc-a7cb-6362c101fd10.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7ae8e4a9-fa5f-4b81-ad03-c630f58be96a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/0f01e971-719b-4bdc-8313.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/49897174-1838-41c8-a6e4-ac26a6f74683.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5f8e3b7b-f7ed-49d5-a721-dffd3df98a94.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/7f096135-a895-45b8-a9e7.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/641a7528-c344-4ee1-a218-a66b1a1d2038.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4e2c7823-a390-4579-a811-90c34515cc4f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/45fd67da-df3d-464b-9740.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/44648cf0-151a-460b-a24d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7555a531-30db-4c9e-a102-d98a9b0c311d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/442ed2cd-80a2-475a-a605-1752450ae7bf.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/681ecaf4-6fc6-4f6e-adc6-45ab1e2f664a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/bd96ab33-37d7-45af-a2cf.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/66c3c61c-dd7a-4e95-a970-f38fb51a75a4.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7b617827-00df-4017-a1ed-4fd63a1c1f89.wav
# loss: 0.3441542983055115
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/19689d82-915f-42c7-beb3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/904df884-bfb0-4ba0-9b40.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/65b18aed-3120-4881-a785-680577a39f13.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/766b27cb-b144-4164-a382-3c121d106541.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/f436b1d1-bb0e-40c5-97dc.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4e31953d-3c15-4619-a9de-b347115aee8f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/1c06ff65-8c78-4542-93c8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7f56eb9d-3861-4ba9-a642-29bf94516ea7.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6c61ab91-9ccf-4aac-a8b3-76b25ba5a149.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6f058d57-1db2-4938-abd0-c43404a5b75a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/f61e81b1-e1cd-4215-9e11.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/3f98929b-a45b-4054-8756.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/53e26d62-424b-44e7-9010.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/72cfc395-6d4c-46cf-acc9-2ef684203295.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5e857f4b-42d5-4fef-a901-31db16940925.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/422b2736-6be2-4039-a95e-12e91754281c.wav
# loss: 0.21478331089019775
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/583f35de-821c-4a0c-a902-8737dfb2ad45.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/453265b9-09f3-474b-a44c-950794f7d5ca.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/93c25ce8-ef78-4049-809c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/2b85a1ae-22dc-410c-b40b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/630d75de-599f-4f65-a021-a047acb73af0.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4ac2caeb-7c1b-4575-ac0a-a5c1a364b70f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7e0c9ec1-05da-4ada-afd1-2bf0eb1900cc.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7a255fff-25b8-4685-a334-88a685172b3f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/64c9650c-0060-4929-a0f3-9bfdd8abd233.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/4f847e7b-201f-45ef-ac4a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4939f028-348b-4e53-aa7c-6c55301b06f9.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6b29d665-bb95-4541-a78b-247c02e83943.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/d7c9bd11-e404-4f36-8e88.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c4c67e81-9aa8-4af4-8eb7.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4af7d6c5-a9b1-4d7c-a7aa-5055cfe38635.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/ac39486a-79de-4c6f-9848.wav
# loss: 0.3530896306037903
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6db78b08-19e1-46fa-aac3-0bcd632776e2.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7062f877-46c7-4695-a0d8-e13dd49363ee.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/57b87864-6bd5-4417-a1e6-bf4697291060.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/43b690ba-b836-4c27-ab90-de283230f0e5.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4099e47b-20ad-4255-a091-c4879855acb7.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/68bf1af0-6574-4630-a333-677531625cab.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/425d95c4-7714-49b4-a139-1d219d6081a3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7b079db4-9e51-4340-ab7b-bfeeec30067e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/55c670b5-5d84-41cf-a3a4-fb4936a9ff0f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/62a6d332-52cb-4225-ad2e-6be5f387ff66.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/b1d31b42-3a5c-4c71-a2ec.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/071e4a68-8020-4363-b13f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/6aae8eb1-bfd8-4a46-ab4a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/71aa15fd-00f4-41fa-a0b3-108b4598e5f4.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/2872c62a-e72d-417d-b795.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/7a5685dc-6b6e-4347-9445.wav
# loss: 0.4040564000606537
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/61fda513-0d58-4448-a6ea-8c7af3fa45b6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/367f061a-cd66-45d5-8f5c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7bc8a24f-4d4a-4ddb-a1fe-d69f6f0cac5f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7da7c88c-13ae-4e24-ac19-7493b859dec6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/55a25026-7f70-4008-aaf7.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/72e8eece-a540-4324-a932-3950fcaed8b9.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5810fb23-ee52-48ce-aedd-ec2d248d7296.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6898e416-13a0-40c1-a3c4-5171f323c1a6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5b0771ac-178c-407f-a057-831cd1ebc045.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/41828bd6-b1a9-4e9c-a098.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/643bdba0-b0d5-421b-a05c-7f269cb3f3b5.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5241dc3b-379a-494d-af9b-89ba70530b83.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5e94725b-1410-4ac2-a6c8-4858323e0324.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/6b6df1d7-0b4e-4e4b-b6c2.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/13c922dc-08cb-4b5e-b574.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5bc1c5c7-2da1-43ee-af2d-8939cd4bb3d6.wav
# loss: 0.507423460483551
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7312d3c0-9104-4ec6-a303-5b7f1d1f48bd.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/53151051-16e6-4b78-acf7-3b79fb7bcf73.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5bbdc911-4db1-4137-a422-3f6fdc0316b6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/9be89321-c03b-45f4-a3b5.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7865c63c-1687-4c59-a271-24db9fe9e3ba.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/471d865a-d595-4582-aa6d-28a73eb5aa70.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6bfb913b-66e9-4207-ad67-34ce30c21708.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/9ce85075-f024-4036-b622.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/75da9585-0260-4e54-af04-4fbd965a9f4d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/9a55a775-384e-4a45-988e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/1c0bff6a-85cf-452a-a180.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4ab78b5c-be06-47fd-abe6-22f10482ad82.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/45f52ac0-6817-4ab7-a23c-f2340d6f365e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/245a29f3-f771-4250-af0b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/51850007-ddc5-4ba8-acfc-d3b2c472b923.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/40f65ee1-1cb2-40d1-a558-2cf1551576ea.wav
# loss: 0.21019035577774048
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4383bfed-9743-417c-acf3-078e05ffc2d6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/60970afe-d6b0-4253-ab1c-d99e565ac773.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/57c12c6a-be65-46a9-adba.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/63348d7f-62aa-4603-adc1-34221d98081a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/741d0081-7c2a-4f13-a375-a3b2c1eb25d9.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7b6ee7ef-cb19-4a9f-a206-7dc4e06a130c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7d1f6d47-247e-4ec0-a59c-4870360711a2.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/479f9eb5-9f66-4ef0-ae2c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/0d8fae0c-e565-4177-adbb.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/20b39b86-bf67-4549-a887.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/492b40b3-f79b-437c-acf1-7a722096431a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/e30cf1ee-f979-4466-afc5.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4d17bb0c-a270-4f0a-a09c-97c2f6fd1768.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/728f927f-df6e-4998-a513-974d493cfbc2.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/665ea314-0b26-40a9-ad98-02ccf1950b70.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/094146f7-8f15-462b-9040.wav
# loss: 0.38935115933418274
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6b5e9e39-4eb0-4702-a8fc-db083700923f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7a88cd49-c254-47ee-acfb-8c8207dc762b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/55e7430f-d05f-46be-a828-94b9e1207549.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/3703fce8-8583-419e-ac61.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/59168ffc-6b02-40ad-a25b-1e0c1e3f32da.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/cb28c0d4-8c6d-42de-8646.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/478c3800-50f0-456f-a0ea-f273d4bfcbbb.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/54353bbf-31c7-4977-a7c2-f5e2cb867c1e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/16f5ed03-ac33-4f2e-850a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/597d9117-50b9-4493-a98a-0ab8dba501f4.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/6829011d-d755-4941-99c1.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/d5940574-8426-4498-8538.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4397d9d8-2bbd-473d-a1c8-2fa1fac587f8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/60e6d4aa-619a-4ca7-a4c9-b87f59f5b918.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4ada5e26-2577-4661-a606-2b3e2895e558.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7869d8d9-7c78-4772-aa72-c6090c43a62b.wav
# loss: 0.8670242428779602
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/59714d4f-7784-4b4e-a914-57e7c091fb51.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/875345c6-2646-4aa1-ae61.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5a99986a-2bcf-4652-ad74-e6f673710d8e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/d050ac04-61e9-4ebb-ae84.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c3e2b60f-6d3c-4509-9b91.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/02eff151-df68-4851-90db.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/488e6a81-1a6f-40ce-ac2d-3509d9abd80d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/50274cce-dcef-49c3-a5f8-46b8379771dd.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4e5fa4ef-b241-4ccd-a439-09f71ad6593d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/72bed791-d446-4dfd-a40e-2bde20c6ec18.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/43bf8654-f894-4d7f-adec-3aa593451095.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/093aaf34-9840-410e-9fd1.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4e2616fe-212f-4613-ad6d-99537dc3089d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/74554382-a605-44b4-a410-86d46c33c832.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7236e985-4862-408d-aa2e-7fa268546879.wav
# ...
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/45add951-8409-448b-ab9b-d6f553e1c78a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/629f2dc5-1a83-4c11-a91f-228db81a6cb3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/80c0ad2e-2c04-4274-be67.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/73c17d02-43ca-406d-a534-502c0f043b7a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/3e926a9a-90e5-4296-99e5.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/214badcd-1634-4c29-a09b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/71d04c85-17bd-4612-853a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4c3fd299-0c3a-4f4b-a1ce-984023289c23.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/550d5e4a-6a8b-4544-a994-b892a96c62ed.wav
# loss: 0.16950561106204987
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6cd19cc1-d4bc-4c75-aa63-da0c6c708d54.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4905b36d-6b8f-47c6-aec6-f5d32eb04456.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c859df63-b828-4755-ab55.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/2720c2ba-1085-442b-82c1.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/48f7af25-130a-4559-a5ca-3460b069688b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c373deba-f59b-42fd-9a7a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7cce19de-cb7f-4204-ad5c-31dde99753e9.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7e318d5f-81a9-43b9-ace5-11766ff8ee63.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5524b5e7-23cb-4b29-a49b-7783afa34dbc.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/209bfd2c-333a-4134-8d01.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/bb0099ce-3073-4613-8557.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/570e7bf1-2365-4571-a0be-661ea01b9671.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/752ca0ac-e7df-4095-a63f-abda6351e734.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/496165f8-cb06-44cd-a4b0-99264fb505cd.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/b0416d44-cca0-447c-8246.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/3661273c-19b9-4ea0-abc5.wav
# loss: 0.21858011186122894
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/49f82a77-7f7f-4c8a-a5d9-d8de2d11102c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5f2459d9-c119-47eb-a96f-25af301e3d40.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/40be2b55-9c11-403a-a6b0-f1fa0ef8d89f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/0ce2ba3e-43a4-41fd-8c5c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/9535791f-efa2-4b88-b270.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4828164e-54c0-435a-a3ad-67d8de670d9f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/faa74f75-5c5d-4ce3-81d7.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/b45fd058-3201-4614-913d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/0a0b783d-f9a3-4652-a01d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/52cd0e5a-bdf3-40df-afe7-0e83a268023b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/47e609de-15b7-4340-ab77-b474307b07b3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5be19165-d2f2-4b82-adab-19a05d076d19.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5ac6b9c2-48a8-490a-a7fc-92ec8192883c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6d9420ce-bd8c-45fa-adb1-04b75336c740.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5785c91c-d60c-4bee-a3e3-5108fe74dfbd.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/76dca7b4-17c5-49ce-aede-28cb9ec923de.wav
# loss: 0.577362060546875
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/894fa4c7-fc14-4f0d-881e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4274e83b-16e4-4eb0-af1a-48d882ff04d0.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6be968b2-371a-4219-a1af-95813a533038.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5962b62b-0792-4562-a51a-7570a1e35c8d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4c82db61-c033-48f9-a8a3-721815d8a5fe.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/49dc683e-c63f-42bb-a585-483411a5e0b8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4f46c6b2-f03a-484d-a182-b78118bc7d63.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/47050eed-0cba-4c53-a71d-4eb2be15d8df.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4d34c0f0-b654-4a66-a1b3-845782b50808.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5a98b01c-62ea-4a84-a2cf-c8d16d0c02ec.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7de45ef6-b631-4330-a66e-6b5cab865210.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/219a813d-11ff-4338-a1c3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6481f90e-a0c9-4859-a1ec-344b5666eb31.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/40e09b4e-a77f-40d8-824c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/385b6ae7-cd20-4c15-becb.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/40378a4f-2deb-4fef-83d3.wav
# loss: 0.31787827610969543
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/6cec3644-8f80-46ae-861b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/bd067bca-2a21-4844-8fd8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/436ac122-e596-4f2f-a308-164499963cc9.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c80383ea-fa0c-4fdb-ac91.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7d4243a1-c94e-41f8-a9ca-28f51eda3728.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5d826e38-4565-46f3-a5f3-f911a36e29d2.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/bf1d2d89-763e-4761-aa4a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4357826e-4dcf-4831-af09-8ca8fbe08349.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/37efd4f5-dfcf-4861-9ba2.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/4344916a-8ecd-4f2d-b55c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5ad697f5-64f6-4bfd-a154-307d42a4390f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6de44764-0fc1-4f35-ac6a-0b5f6330b8eb.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7433704f-16f7-4545-afb9-5f31ecb5b555.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7d29a888-68d0-434f-ab96-d8c28b687a6a.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/9752a466-ce2a-4baa-be26.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7b381d22-c6f2-4ab0-a00c-4d63bb4cfd10.wav
# loss: 0.2806106507778168
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/54c4f20f-949a-4acb-a587-c68eb428b300.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c37d50e4-7ebe-44b4-a83e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5341d008-8767-43b6-a350-1fe0cf6d5d1b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/d0f75e8a-6811-443b-b708.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4f1eaec1-ccaf-4ca0-a91c-43574797e4be.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/93289964-253a-4b35-a936.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/653669da-63db-4314-af40-47841b3f0e6c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7736ab8d-ce9c-44ca-a40e-73e2e9fab2b7.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7e81ab20-f4d3-4e88-a7da-174ad4bdbedc.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/7e67c1dc-317a-4cd9-a79d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/55675981-f3e6-41ad-a8af-3cafa4d14b91.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6a47f208-7b27-4ed3-a324-262b765649b1.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/9431cf02-0a83-4da3-90c8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/ffcb93e5-363b-4c9d-8d7e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6c1c612e-9165-4d21-a0d9-143c7826e4af.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5f27d222-b59f-4ccd-ac24-0d4edbbd37a7.wav
# loss: 0.33130279183387756
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5a4ca30c-f032-412b-a366-66d20249fea6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6634b987-bb73-47f2-a585-a49bde7e6a49.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/1db06bb1-b4a9-4fe4-8a22.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/86f13bcd-76b3-4bfe-8428.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5456a32f-4579-4bb5-afc8-a936c2f3934d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/7f4c62e9-7b10-464a-9950.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/e329623e-b45b-4ec7-9891.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/018f6b70-e650-4d1f-b6d3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/55b351ec-7776-40ce-a103-f92fa815ece4.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5135e8f6-533e-47fe-a915-1ea84a1e43d2.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4190b699-adbc-4a89-a69f-b2361ac04113.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6784f2e0-b030-4679-ada3-e1a7db59b011.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/54fb573f-5d88-4e56-ada6-5caf722d6051.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/799d5413-8eea-44b4-a770-69716350dde1.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7ae2a7bb-c188-4d94-ac9a-0745c3156fb3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/66b780d9-c038-463f-ac30.wav
# loss: 0.09354081749916077
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5b8d5213-4996-473c-aff5-40b2e8e069e8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6acca3f1-86ee-4ff9-a367-778a87d2fac5.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/cdab48ee-1302-4540-af84.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/39f568b9-e340-4e43-ab69.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/53fcd999-f037-4328-a790-db294bdfc848.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/fa2ea780-8b6e-4d8c-abe0.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7f8eda1a-7c4c-4742-ac0a-1ee62253a494.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5e9432b4-0779-4774-a555-e86e23e6d42c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7c374a27-e22c-41fb-aa52-d13fc23b6dc3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/08401494-9bb8-46da-bef6.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/70afb8ce-4859-49e7-acd7-6ab2049aede8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c806b2c4-5596-4cfd-a6f9.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7ed06f6c-c240-4d72-ab71-847fc8c24754.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/6da76f36-e0da-4cc2-8b4b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/62e787a2-5352-435b-aad7-437876a4bd51.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/508d0c8c-b145-475b-a6c1-78445bd3a275.wav
# loss: 0.3713693618774414
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/443e89a2-4f3d-40fe-a7ce-1d73d46047a0.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/e0a465da-4041-4e8f-84ef.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/57795671-2358-435c-a95e-8605ff13b5e3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6d96063a-2d1e-4260-a55d-59ce474c6077.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5ad2a77a-dc3d-4798-af2d-0646213b199b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5e527584-8a98-4067-ac86-e0c0a34861ab.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7b9cb449-f9e6-4614-ad3c-5a680be1a61b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/74a1bbc3-2293-4261-a1c6-fb6e3f854ace.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/45941646-1955-48b6-a674-cba5d128a8fb.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4d85d0bf-f013-4290-ac04-7b4767c53952.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c64e7f01-1129-424b-bf9e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/5f7a2048-1463-425a-ae5a-c1714e8f32d7.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/ca27ac54-da78-40d6-9bf8.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/73961e24-720c-4d41-aa67-d49a2e07d890.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/742553f2-bedd-4509-a2c7-bc561e2bb36c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/02c75126-970c-469b-999f.wav
# loss: 0.4348577857017517
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/13d25b74-e092-4484-b5b7.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/47450a5d-a45e-4537-af05-11b3acd33c29.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/716671dd-7c4a-4557-ae55-b9823f4f1139.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/c77afec6-fb94-42e4-9131.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/8172780f-abed-4641-89df.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/45b73e4c-22ba-4a7c-b812.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/f1a0251d-407c-4a41-940d.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/9311bc6f-9b70-4d9e-9d27.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/6325c90c-9c4f-4e9f-bd64.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7d0c9834-afdd-41a4-a940-f299aa7eb784.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4db50734-f27e-432f-a02d-0e1cb87fea91.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6bf87e0e-f27e-4c2d-a707-712e5c106ca3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/4463ad0d-4d47-4c7d-a1e6-213927a13f8b.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/50aef44e-7862-4f94-ae3c-4c18890031a3.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/42a6a981-51e9-48bf-a2fa-b81e7bebee4f.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6e193bef-9a7c-40ba-aa67-3589b8ebc3d9.wav
# loss: 0.4696836471557617
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6c48fcf0-5c4e-47f8-a9c8-4c099e5b3ddf.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/63dcfcb0-16c9-4f0b-ac4e-8b1e9a001483.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/6c09c2c7-d477-46da-a9c8-ea09dff7655c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/744ade99-4677-4f63-a99b-673d84d178ce.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/51fc5194-a4a1-45f3-a47d-b11a6e89d36c.wav
# /content/drive/My Drive/DCASE_Datasets/audio/BirdVox-DCASE-20k/7ddfec46-f8ca-4b6e-a31c-ee56e92a31ed.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/d832862c-e818-4304-8f7e.wav
# /content/drive/My Drive/DCASE_Datasets/audio/warblrb10k/8b597722-b475-413d-8975.wav
# loss: 0.34637367725372314
# Average loss: 0.3124454005464027
# ---------------------------
# Finished training
# Trained cnn saved at cnn.pth

# %%
import torch
import torchaudio
from torch import nn

from random import seed
from random import random
import matplotlib
import matplotlib.pyplot as plt

from dcasedatasetcpu import DCASE_Dataset
# from cnnbinary_uky import CNNNetwork
# from train_binary import ANNOTATIONS_FILE, AUDIO_DIR, SAMPLE_RATE, DURATION, NUM_SAMPLES

ANNOTATIONS_birdvox = '/content/drive/My Drive/DCASE_Datasets/labels/BirdVox-DCASE20k.csv'
ANNOTATIONS_warblr = '/content/drive/My Drive/DCASE_Datasets/labels/warblrb10k.csv'
ANNOTATIONS_freefield = '/content/drive/My Drive/DCASE_Datasets/labels/ff1010bird.csv'
ANNOTATIONS_mini = '/content/drive/My Drive/DCASE_Datasets/labels/mini_metadata.csv'
AUDIO_DIR = '/content/drive/My Drive/DCASE_Datasets/audio/'
SAMPLE_RATE = 22050
DURATION = 10
NUM_SAMPLES = 22050 * DURATION
THRESHOLD = 0.5


class_mapping = [
    "no-bird",
    "bird"
]


def predict(model, input, target, class_mapping):
    model.eval()
    with torch.no_grad():
        predictions = model(input).cuda()
        sigmoid = nn.Sigmoid()
        predictions = sigmoid(predictions)
        print(predictions)
        # Tensor (1, 10) -> [ [0.1, 0.01, ..., 0.6] ]
        if predictions[0] > THRESHOLD:

          # predicted_index = predictions[0].argmax(0)
          predicted_index = 1
        elif predictions[0] < THRESHOLD:
          predicted_index = 0
        print(predicted_index)
        predicted = class_mapping[predicted_index]
        expected = class_mapping[target]
    return predicted, expected


if __name__ == "__main__":
    # load back the model
    cnn = CNNNetwork()
    state_dict = torch.load("/content/drive/My Drive/MSc_Project_Colab/BAD_PyTorch/cnn.pth", map_location=torch.device('cpu'))
    cnn.load_state_dict(state_dict)

    # load DCASE dataset
    mel_spectrogram = torchaudio.transforms.MelSpectrogram(
        sample_rate=SAMPLE_RATE,
        n_fft=1024,
        hop_length=316,
        n_mels=80,
        power=0.33
    )

    t1masking = torchaudio.transforms.TimeMasking(time_mask_param=40)
    t2masking = torchaudio.transforms.TimeMasking(time_mask_param=40)
    fmasking = torchaudio.transforms.FrequencyMasking(freq_mask_param=10)

    dcase = DCASE_Dataset(ANNOTATIONS_freefield,
                            AUDIO_DIR,
                            mel_spectrogram,
                            SAMPLE_RATE,
                            NUM_SAMPLES,
                            "cpu")


    # get a sample from the dcase dataset for inference
    num_files = 1000

    count = 0
    index = 0
    correct = 0
    countnobird = 0
    countbird = 0
    while count < num_files:
  
      value = random()
      val_label = random()

      input, target = dcase[index][0], dcase[index][1]


      if target == 0:
        if val_label < 0.667:
          index += 1
          continue

      if value > 0.75:
        input = t1masking(input)
        input = t2masking(input)
        input = fmasking(input)
        input = input

      # def plot_spectrogram(spec, title=None, ylabel='freq_bin', aspect='auto', xmax=None):
      #     fig, axs = plt.subplots(1, 1)
      #     axs.set_title(title or 'Spectrogram')
      #     axs.set_ylabel(ylabel)
      #     axs.set_xlabel('frame')
      #     spec = spec.cpu()
      #     spec = spec[0,:,:]
      #     im = axs.imshow(spec, origin='lower', aspect=aspect)
      #     if xmax:
      #       axs.set_xlim((0, xmax))
      #     fig.colorbar(im, ax=axs)
      #     plt.show(block=False)

      
      # plot_spectrogram(input)


      input.unsqueeze_(0)

      index += 1
      count += 1

      if target == 1:
        countbird += 1
      else:
        countnobird += 1

    # make an inference
      predicted, expected = predict(cnn, input, target,
                                  class_mapping)
      if predicted == expected:
        correct += 1
      print(f"Predicted: '{predicted}', expected: '{expected}'")
      print()

    accuracy = correct / num_files
    print(accuracy)
    print("bird: {}".format(countbird))
    print("no-bird: {}".format(countnobird))
# Out:
# Streaming output truncated to the last 5000 lines.
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/47181.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/47181.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/72011.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/72011.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157227.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157227.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/59176.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/59176.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/29982.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/29982.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/54640.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/54640.wav
# tensor([[0.9940]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/7543.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/7543.wav
# tensor([[0.8697]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/68380.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/68380.wav
# tensor([[0.7779]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/75248.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/75248.wav
# tensor([[0.8828]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/70958.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/70958.wav
# tensor([[0.9900]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/84687.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/84687.wav
# tensor([[0.9697]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/167569.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/167569.wav
# tensor([[0.9664]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/173897.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/173897.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/38886.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/38886.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/189583.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/189583.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/69962.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/69962.wav
# tensor([[0.9200]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/7996.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/7996.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/1945.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/1945.wav
# tensor([[0.4951]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/347.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/347.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/56301.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/56301.wav
# tensor([[0.8829]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/167370.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/167370.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/72010.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/72010.wav
# tensor([[0.6363]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/195862.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/195862.wav
# tensor([[0.3524]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/127281.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/127281.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/124733.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/124733.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/3182.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/3182.wav
# tensor([[0.0372]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/57062.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/57062.wav
# tensor([[0.3406]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/155203.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/155203.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/57035.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/57035.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/73282.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/73282.wav
# tensor([[0.8622]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/164120.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/164120.wav
# tensor([[0.3275]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/21245.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/21245.wav
# tensor([[0.9721]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/45336.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/45336.wav
# tensor([[0.9238]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/30034.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/30034.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/57034.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/57034.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/37930.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/37930.wav
# tensor([[0.9112]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/54595.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/54595.wav
# tensor([[0.8524]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/146860.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/146860.wav
# tensor([[0.6785]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/43717.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/43717.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/104649.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/104649.wav
# tensor([[0.8515]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/169041.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/169041.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/67483.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/67483.wav
# tensor([[0.9670]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/148356.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/148356.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/78794.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/78794.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/7542.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/7542.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157883.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157883.wav
# tensor([[0.2603]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/179738.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/179738.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/17075.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/17075.wav
# tensor([[0.4832]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/44111.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/44111.wav
# tensor([[0.9620]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/185121.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/185121.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/108770.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/108770.wav
# tensor([[0.9753]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140204.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140204.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/63726.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/63726.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/5929.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/5929.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/121572.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/121572.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/66046.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/66046.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/162686.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/162686.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/163727.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/163727.wav
# tensor([[0.3421]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/167406.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/167406.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/156597.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/156597.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/188065.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/188065.wav
# tensor([[0.9651]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140158.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140158.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/31909.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/31909.wav
# tensor([[0.9977]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/86749.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/86749.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/173893.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/173893.wav
# tensor([[0.6060]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/188937.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/188937.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/111049.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/111049.wav
# tensor([[0.1874]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/162744.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/162744.wav
# tensor([[0.3397]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/54914.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/54914.wav
# tensor([[0.9898]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/127370.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/127370.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/91991.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/91991.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/120375.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/120375.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/170338.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/170338.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/126042.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/126042.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/61631.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/61631.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/56947.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/56947.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/79268.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/79268.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/78792.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/78792.wav
# tensor([[0.9964]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/159449.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/159449.wav
# tensor([[0.4538]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/76685.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/76685.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/80792.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/80792.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/180920.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/180920.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/164174.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/164174.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/97381.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/97381.wav
# tensor([[0.6915]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/51372.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/51372.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/133091.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/133091.wav
# tensor([[0.9046]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/15553.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/15553.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/153376.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/153376.wav
# tensor([[0.9976]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/71823.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/71823.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/121304.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/121304.wav
# tensor([[0.9754]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/102074.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/102074.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/127240.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/127240.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/32311.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/32311.wav
# tensor([[0.9997]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/121356.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/121356.wav
# tensor([[0.9674]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/132045.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/132045.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/131238.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/131238.wav
# tensor([[0.4990]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/57067.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/57067.wav
# tensor([[0.7498]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/45486.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/45486.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/56549.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/56549.wav
# tensor([[0.0583]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/147819.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/147819.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/100883.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/100883.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/54033.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/54033.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/61363.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/61363.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157864.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157864.wav
# tensor([[0.1820]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/117786.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/117786.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/127262.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/127262.wav
# tensor([[0.5349]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/147945.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/147945.wav
# tensor([[0.6482]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/50424.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/50424.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/74468.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/74468.wav
# tensor([[0.4293]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/194489.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/194489.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/117783.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/117783.wav
# tensor([[0.7167]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/144019.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/144019.wav
# tensor([[0.3509]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/148817.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/148817.wav
# tensor([[0.4110]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/195343.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/195343.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/48161.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/48161.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/113441.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/113441.wav
# tensor([[0.9102]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/47052.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/47052.wav
# tensor([[0.9945]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/89690.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/89690.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/80716.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/80716.wav
# tensor([[0.9512]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/98941.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/98941.wav
# tensor([[0.5971]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/122191.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/122191.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/49408.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/49408.wav
# tensor([[0.8950]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/65811.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/65811.wav
# tensor([[0.3601]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/110913.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/110913.wav
# tensor([[0.2721]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/101236.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/101236.wav
# tensor([[0.3130]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/61496.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/61496.wav
# tensor([[0.8751]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/44881.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/44881.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/62602.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/62602.wav
# tensor([[0.4256]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/35722.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/35722.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/63693.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/63693.wav
# tensor([[0.7483]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/5997.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/5997.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/90338.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/90338.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/58274.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/58274.wav
# tensor([[0.3288]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/59765.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/59765.wav
# tensor([[0.8757]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/123142.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/123142.wav
# tensor([[0.4470]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/114627.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/114627.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/80745.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/80745.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/71121.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/71121.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/89054.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/89054.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/36596.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/36596.wav
# tensor([[0.9826]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/189851.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/189851.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/56367.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/56367.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/11685.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/11685.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/104501.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/104501.wav
# tensor([[0.9999]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/160489.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/160489.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/46348.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/46348.wav
# tensor([[0.1825]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/180542.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/180542.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/126333.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/126333.wav
# tensor([[0.4858]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/117890.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/117890.wav
# tensor([[0.9959]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/158598.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/158598.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/43708.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/43708.wav
# tensor([[0.3831]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/108697.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/108697.wav
# tensor([[0.9705]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/90084.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/90084.wav
# tensor([[0.4311]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/56958.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/56958.wav
# tensor([[0.5503]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/169037.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/169037.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/113355.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/113355.wav
# tensor([[0.3597]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187132.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187132.wav
# tensor([[0.9380]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/74514.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/74514.wav
# tensor([[0.9973]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/96175.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/96175.wav
# tensor([[0.2164]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/155285.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/155285.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/31154.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/31154.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/108355.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/108355.wav
# tensor([[0.2704]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/80314.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/80314.wav
# tensor([[0.8767]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/55240.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/55240.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/34619.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/34619.wav
# tensor([[0.2620]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/122063.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/122063.wav
# tensor([[0.4805]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/42786.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/42786.wav
# tensor([[0.8803]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/45910.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/45910.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/14909.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/14909.wav
# tensor([[0.9401]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/148652.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/148652.wav
# tensor([[0.1868]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/148288.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/148288.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/155296.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/155296.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/149928.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/149928.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/91032.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/91032.wav
# tensor([[0.9664]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/102068.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/102068.wav
# tensor([[0.9047]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/150947.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/150947.wav
# tensor([[0.3785]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/58174.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/58174.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/46225.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/46225.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/150338.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/150338.wav
# tensor([[0.4380]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/91286.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/91286.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/39943.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/39943.wav
# tensor([[0.8956]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/38303.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/38303.wav
# tensor([[0.9754]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/90342.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/90342.wav
# tensor([[0.9625]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187075.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187075.wav
# tensor([[0.4398]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/21322.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/21322.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/78922.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/78922.wav
# tensor([[0.2894]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/156227.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/156227.wav
# tensor([[0.8497]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/86748.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/86748.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/39659.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/39659.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/3187.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/3187.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/95692.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/95692.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/16837.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/16837.wav
# tensor([[0.8616]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/162732.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/162732.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/188701.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/188701.wav
# tensor([[0.8901]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/118327.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/118327.wav
# tensor([[0.4799]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/76904.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/76904.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/31256.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/31256.wav
# tensor([[0.3525]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/44569.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/44569.wav
# tensor([[0.4785]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/87456.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/87456.wav
# tensor([[0.9964]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/12699.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/12699.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/79564.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/79564.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/127360.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/127360.wav
# tensor([[0.6595]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/112203.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/112203.wav
# tensor([[0.9627]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/97973.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/97973.wav
# tensor([[0.9791]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/66350.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/66350.wav
# tensor([[0.7120]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/17136.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/17136.wav
# tensor([[0.3576]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/176250.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/176250.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/20988.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/20988.wav
# tensor([[0.9864]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/172443.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/172443.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/116847.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/116847.wav
# tensor([[0.4741]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/105395.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/105395.wav
# tensor([[0.8667]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/82539.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/82539.wav
# tensor([[0.5172]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/164163.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/164163.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/181400.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/181400.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/87519.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/87519.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/82905.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/82905.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/55121.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/55121.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140710.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140710.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/73354.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/73354.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/73082.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/73082.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/67191.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/67191.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/17147.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/17147.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/52836.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/52836.wav
# tensor([[0.9591]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/110916.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/110916.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/128015.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/128015.wav
# tensor([[0.7877]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/59445.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/59445.wav
# tensor([[0.3437]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/15225.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/15225.wav
# tensor([[0.9988]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/107224.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/107224.wav
# tensor([[0.5283]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/173896.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/173896.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/155048.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/155048.wav
# tensor([[0.1251]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/148154.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/148154.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/167403.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/167403.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/38396.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/38396.wav
# tensor([[0.3532]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/80793.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/80793.wav
# tensor([[0.5306]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/63583.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/63583.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/162693.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/162693.wav
# tensor([[0.4499]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/104520.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/104520.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/38888.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/38888.wav
# tensor([[0.1441]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/44698.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/44698.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/180530.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/180530.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140805.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140805.wav
# tensor([[0.9282]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/176247.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/176247.wav
# tensor([[0.6201]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/169024.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/169024.wav
# tensor([[0.9982]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/69091.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/69091.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/74469.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/74469.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/22863.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/22863.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/63507.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/63507.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/150328.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/150328.wav
# tensor([[0.4820]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/86646.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/86646.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/5996.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/5996.wav
# tensor([[0.1053]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/33444.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/33444.wav
# tensor([[0.8076]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/43778.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/43778.wav
# tensor([[0.9655]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/94415.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/94415.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/15226.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/15226.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/165388.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/165388.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157915.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157915.wav
# tensor([[0.2935]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/18755.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/18755.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140350.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140350.wav
# tensor([[0.2638]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/75088.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/75088.wav
# tensor([[0.9305]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187129.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187129.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/36735.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/36735.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/81049.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/81049.wav
# tensor([[0.3408]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/60033.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/60033.wav
# tensor([[0.9348]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/104287.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/104287.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/181232.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/181232.wav
# tensor([[0.2047]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/65471.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/65471.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/69106.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/69106.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/93756.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/93756.wav
# tensor([[0.9962]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/38732.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/38732.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/89958.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/89958.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/65337.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/65337.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/111080.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/111080.wav
# tensor([[0.5141]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/155229.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/155229.wav
# tensor([[0.8257]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/159999.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/159999.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/191911.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/191911.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/109232.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/109232.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/38279.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/38279.wav
# tensor([[0.5063]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157192.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157192.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/131032.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/131032.wav
# tensor([[0.2358]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/56909.wav
# ...
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/155217.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157643.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157643.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/135488.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/135488.wav
# tensor([[0.9764]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/40552.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/40552.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157380.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157380.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/155249.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/155249.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/104429.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/104429.wav
# tensor([[0.7759]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/69306.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/69306.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/78500.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/78500.wav
# tensor([[0.3267]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140822.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140822.wav
# tensor([[0.8724]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/137880.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/137880.wav
# tensor([[0.2308]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/121303.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/121303.wav
# tensor([[0.5361]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/66598.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/66598.wav
# tensor([[0.8735]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/120902.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/120902.wav
# tensor([[0.9152]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/54801.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/54801.wav
# tensor([[0.9987]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/20204.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/20204.wav
# tensor([[0.8793]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/128740.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/128740.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/162676.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/162676.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/139964.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/139964.wav
# tensor([[0.6500]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/17078.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/17078.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187658.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187658.wav
# tensor([[0.0560]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/25386.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/25386.wav
# tensor([[0.5047]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/58558.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/58558.wav
# tensor([[0.9836]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/101384.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/101384.wav
# tensor([[0.4245]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/117407.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/117407.wav
# tensor([[0.8229]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/147936.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/147936.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/16994.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/16994.wav
# tensor([[0.3590]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/56878.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/56878.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/149250.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/149250.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/117784.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/117784.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/33446.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/33446.wav
# tensor([[0.7681]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187208.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187208.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/130869.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/130869.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/168054.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/168054.wav
# tensor([[0.0832]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/18929.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/18929.wav
# tensor([[0.9768]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/160142.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/160142.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140075.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140075.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/178428.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/178428.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/56950.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/56950.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/194370.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/194370.wav
# tensor([[0.2762]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/163454.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/163454.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/89959.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/89959.wav
# tensor([[0.6945]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/133085.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/133085.wav
# tensor([[0.4412]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/96919.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/96919.wav
# tensor([[0.9816]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187829.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187829.wav
# tensor([[0.5977]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/3183.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/3183.wav
# tensor([[0.5121]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/180159.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/180159.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/87613.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/87613.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187135.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187135.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/150974.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/150974.wav
# tensor([[0.9526]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/77779.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/77779.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187134.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/187134.wav
# tensor([[0.1643]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/159438.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/159438.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/162752.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/162752.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/73222.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/73222.wav
# tensor([[0.9939]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/87558.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/87558.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/194713.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/194713.wav
# tensor([[0.4749]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/118212.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/118212.wav
# tensor([[0.9793]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/104937.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/104937.wav
# tensor([[0.9986]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/104519.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/104519.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/84541.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/84541.wav
# tensor([[0.5025]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/159443.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/159443.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/90339.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/90339.wav
# tensor([[0.3309]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/65298.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/65298.wav
# tensor([[0.8609]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/186335.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/186335.wav
# tensor([[0.8133]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/111669.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/111669.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/162180.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/162180.wav
# tensor([[0.6737]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140795.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/140795.wav
# tensor([[0.8253]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/132363.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/132363.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157580.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/157580.wav
# tensor([[0.5167]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/70956.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/70956.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/78926.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/78926.wav
# tensor([[0.3045]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/76273.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/76273.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/24952.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/24952.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/57799.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/57799.wav
# tensor([[0.8429]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/159988.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/159988.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/73370.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/73370.wav
# tensor([[0.1561]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/32405.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/32405.wav
# tensor([[0.1595]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/78501.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/78501.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/39637.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/39637.wav
# tensor([[0.6600]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/128370.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/128370.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/44063.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/44063.wav
# tensor([[0.0718]], device='cuda:0')
# 0
# Predicted: 'no-bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/52298.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/52298.wav
# tensor([[0.9737]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/13779.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/13779.wav
# tensor([[0.7596]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/160013.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/160013.wav
# tensor([[0.9928]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/68032.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/68032.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/145486.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/145486.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/7126.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/7126.wav
# tensor([[0.6149]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'no-bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/25823.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/25823.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/70150.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/70150.wav
# tensor([[0.9994]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/54951.wav
# /content/drive/My Drive/DCASE_Datasets/audio/ff1010bird/54951.wav
# tensor([[0.9677]], device='cuda:0')
# 1
# Predicted: 'bird', expected: 'bird'
#
# 0.704
# bird: 507
# no-bird: 493
